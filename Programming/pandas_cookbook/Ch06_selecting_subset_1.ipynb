# %%
import pandas as pd
import numpy as np
from pathlib import Path
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns

# %%
p1 = Path.cwd() / 'data'

# %%
college = pd.read_csv(p1 / 'college.csv', index_col='INSTNM')
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
# ...

# %%
city = college['CITY']
city
# Out:
# INSTNM
# Alabama A & M University                                            Normal
# University of Alabama at Birmingham                             Birmingham
# Amridge University                                              Montgomery
# University of Alabama in Huntsville                             Huntsville
# Alabama State University                                        Montgomery
#                                                                 ...
# SAE Institute of Technology  San Francisco                      Emeryville
# Rasmussen College - Overland Park                            Overland Park
# National Personal Training Institute of Cleveland         Highland Heights
# Bay Area Medical Academy - San Jose Satellite Location            San Jose
# Excel Learning Center-San Antonio South                        San Antonio
# Name: CITY, Length: 7535, dtype: object

# %%
alabama = city.isin(['Birmingham', 'Montgomery'])
city[alabama]
# Out:
# INSTNM
# University of Alabama at Birmingham                 Birmingham
# Amridge University                                  Montgomery
# Alabama State University                            Montgomery
# Auburn University at Montgomery                     Montgomery
# Birmingham Southern College                         Birmingham
# South University-Montgomery                         Montgomery
# Faulkner University                                 Montgomery
# Herzing University-Birmingham                       Birmingham
# Huntingdon College                                  Montgomery
# Jefferson State Community College                   Birmingham
# Lawson State Community College-Birmingham Campus    Birmingham
# Samford University                                  Birmingham
# Southeastern Bible College                          Birmingham
# H Councill Trenholm State Community College         Montgomery
# West Virginia University Institute of Technology    Montgomery
# ...

# %%
city['Alabama A & M University':'Alabama State University'], city.loc['Alabama A & M University':'Alabama State University']
# Out:
# (INSTNM
#  Alabama A & M University                   Normal
#  University of Alabama at Birmingham    Birmingham
#  Amridge University                     Montgomery
#  University of Alabama in Huntsville    Huntsville
#  Alabama State University               Montgomery
#  Name: CITY, dtype: object,
#  INSTNM
#  Alabama A & M University                   Normal
#  University of Alabama at Birmingham    Birmingham
#  Amridge University                     Montgomery
#  University of Alabama in Huntsville    Huntsville
#  Alabama State University               Montgomery
#  Name: CITY, dtype: object)

# %%
city.loc['Alabama State University':'Alabama A & M University':-1]
# Out:
# INSTNM
# Alabama State University               Montgomery
# University of Alabama in Huntsville    Huntsville
# Amridge University                     Montgomery
# University of Alabama at Birmingham    Birmingham
# Alabama A & M University                   Normal
# Name: CITY, dtype: object

# %%
college.iloc[60, :].equals(college.loc['University of Alaska Anchorage', :])
# Out:
# True

# %%
start = 'Empire Beauty School-Flagstaff'
stop = 'Arizona State University-Tempe'
college.loc[start:stop:-1, :]
# Out:
#                                                         CITY STABBR  HBCU  \
# INSTNM
# Empire Beauty School-Flagstaff                     Flagstaff     AZ   0.0
# Cochise County Community College District            Douglas     AZ   0.0
# Charles of Italy Beauty College             Lake Havasu City     AZ   0.0
# Brown Mackie College-Tucson                           Tucson     AZ   0.0
# Central Arizona College                             Coolidge     AZ   0.0
# Southwest University of Visual Arts-Tucson            Tucson     AZ   0.0
# University of Arizona                                 Tucson     AZ   0.0
# Arizona Western College                                 Yuma     AZ   0.0
# Arizona State University-Tempe                         Tempe     AZ   0.0
#
#                                             MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Empire Beauty School-Flagstaff                  0.0        0.0         0
# ...

# %%
college.iloc[[60, 99, 3], :].index.tolist()
# Out:
# ['University of Alaska Anchorage',
#  'International Academy of Hair Design',
#  'University of Alabama in Huntsville']

# %%
college.iloc[:3, :4]
# Out:
#                                            CITY STABBR  HBCU  MENONLY
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0

# %%
college.iloc[:, [4, 6]].columns
# Out:
# Index(['WOMENONLY', 'SATVRMID'], dtype='object')

# %%
college.iloc[5, -4]
# Out:
# 0.401

# %%
col_start = college.columns.get_loc('UGDS_WHITE')
col_end = college.columns.get_loc('UGDS_UNKN') + 1
col_start, col_end
# Out:
# (10, 19)

# %%
college.iloc[:5, col_start:col_end]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
row_start = college.index[10]
row_end = college.index[15]
college.loc[row_start:row_end, 'UGDS_WHITE']
# Out:
# INSTNM
# Birmingham Southern College                 0.7983
# Chattahoochee Valley Community College      0.4661
# Concordia College Alabama                   0.0280
# South University-Montgomery                 0.3046
# Enterprise State Community College          0.6408
# James H Faulkner State Community College    0.6979
# Name: UGDS_WHITE, dtype: float64

# %%
college = college.sort_index()
college.head()
# Out:
#                                                            CITY STABBR  HBCU  \
# INSTNM
# A & W Healthcare Educators                          New Orleans     LA   0.0
# A T Still University of Health Sciences              Kirksville     MO   0.0
# ABC Beauty Academy                                      Garland     TX   0.0
# ABC Beauty College Inc                              Arkadelphia     AR   0.0
# AI Miami International University of Art and De...        Miami     FL   0.0
#
#                                                     MENONLY  WOMENONLY  \
# INSTNM
# A & W Healthcare Educators                              0.0        0.0
# A T Still University of Health Sciences                 0.0        0.0
# ABC Beauty Academy                                      0.0        0.0
# ABC Beauty College Inc                                  0.0        0.0
# AI Miami International University of Art and De...      0.0        0.0
#
# ...

# %%
college.loc['Sp':'Su', 'UGDS_WHITE']
# Out:
# INSTNM
# Spa Tech Institute-Ipswich                    0.9459
# Spa Tech Institute-Plymouth                   0.7124
# Spa Tech Institute-Westboro                   0.8222
# Spa Tech Institute-Westbrook                  0.9417
# Spalding University                           0.6650
#                                                ...
# Studio Academy of Beauty                      0.4669
# Studio Jewelers                               0.2545
# Stylemaster College of Hair Design            0.9481
# Styles and Profiles Beauty College            0.8710
# Styletrends Barber and Hairstyling Academy    0.0000
# Name: UGDS_WHITE, Length: 201, dtype: float64

# %%
college.index.is_monotonic_increasing
# Out:
# True
