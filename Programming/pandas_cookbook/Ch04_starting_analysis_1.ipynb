# %%
import pandas as pd
import numpy as np
from pathlib import Path
from pandas.testing import assert_frame_equal

# %%
p1 = Path.cwd() / 'data'

# %%
college = pd.read_csv(p1 / 'college.csv')
different_cols = ['RELAFFIL', 'SATMTMID', 'CURROPER', 'INSTNM', 'STABBR']
col2 = college[different_cols]
col2.head()
# Out:
#    RELAFFIL  SATMTMID  CURROPER                               INSTNM STABBR
# 0         0     420.0         1             Alabama A & M University     AL
# 1         0     565.0         1  University of Alabama at Birmingham     AL
# 2         1       NaN         1                   Amridge University     AL
# 3         0     590.0         1  University of Alabama in Huntsville     AL
# 4         0     430.0         1             Alabama State University     AL

# %%
college.sample(n=5, random_state=0)
# Out:
#                                      INSTNM       CITY STABBR  HBCU  MENONLY  \
# 1121  The Illinois Institute of Art-Chicago    Chicago     IL   0.0      0.0
# 3381          Valley Forge Military College      Wayne     PA   0.0      0.0
# 6051      Regency Beauty Institute-Columbus   Columbus     OH   0.0      0.0
# 4229     Georgia Piedmont Technical College  Clarkston     GA   0.0      0.0
# 5809        Regency Beauty Institute-Duluth     Duluth     MN   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 1121        0.0         0       NaN       NaN           0.0  ...     0.0006
# 3381        0.0         0     394.0     402.0           0.0  ...     0.0497
# 6051        0.0         0       NaN       NaN           0.0  ...     0.0638
# 4229        0.0         0       NaN       NaN           0.0  ...     0.0197
# 5809        0.0         0       NaN       NaN           0.0  ...     0.0870
#
# ...

# %%
college.shape
# Out:
# (7535, 27)

# %%
college.describe(include='number').T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# ...

# %%
college.describe(include='object').T
# Out:
#                    count unique                       top  freq
# INSTNM              7535   7535  Alabama A & M University     1
# CITY                7535   2514                  New York    87
# STABBR              7535     59                        CA   773
# MD_EARN_WNE_P10     6413    598         PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038         PrivacySuppressed  1510

# %%
col2.memory_usage(deep=True)
# Out:
# Index          128
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
col2.dtypes
# Out:
# RELAFFIL      int64
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
col2['RELAFFIL'].nunique()
# Out:
# 2

# %%
col2.select_dtypes(include='object').nunique()
# Out:
# INSTNM    7535
# STABBR      59
# dtype: int64

# %%
movie = pd.read_csv(p1 / 'movie.csv')
cols = ['movie_title', 'imdb_score', 'budget']
mov2 = movie[cols]

# %%
mov2.nlargest(100, 'imdb_score').nsmallest(10, 'budget')
# Out:
#                          movie_title  imdb_score     budget
# 4804                  Butterfly Girl         8.7   180000.0
# 4801              Children of Heaven         8.5   180000.0
# 4706                    12 Angry Men         8.9   350000.0
# 4550                    A Separation         8.4   500000.0
# 4636            The Other Dream Team         8.4   500000.0
# 2215                          Psycho         8.5   806947.0
# 4425                      Casablanca         8.6   950000.0
# 4397  The Good, the Bad and the Ugly         8.9  1200000.0
# 4395                  Reservoir Dogs         8.4  1200000.0
# 4369          Queen of the Mountains         8.7  1400000.0

# %%
mov2[mov2['imdb_score'] >= mov2['imdb_score'].nlargest(100).min()].nsmallest(5, 'budget')
# Out:
#                     movie_title  imdb_score    budget
# 4815  A Charlie Brown Christmas         8.4  150000.0
# 4801         Children of Heaven         8.5  180000.0
# 4804             Butterfly Girl         8.7  180000.0
# 4706               12 Angry Men         8.9  350000.0
# 4550               A Separation         8.4  500000.0

# %%
cols2 = ['movie_title', 'title_year', 'imdb_score']
mov3 = movie[cols2].dropna(how='any')

# %%
mov3.head()
# Out:
#                                 movie_title  title_year  imdb_score
# 0                                    Avatar      2009.0         7.9
# 1  Pirates of the Caribbean: At World's End      2007.0         7.1
# 2                                   Spectre      2015.0         6.8
# 3                     The Dark Knight Rises      2012.0         8.5
# 5                               John Carter      2012.0         6.6

# %%
mov3.groupby('title_year', as_index=False)['imdb_score'].max()
# Out:
#     title_year  imdb_score
# 0       1916.0         8.0
# 1       1920.0         4.8
# 2       1925.0         8.3
# 3       1927.0         8.3
# 4       1929.0         8.0
# ..         ...         ...
# 86      2012.0         8.5
# 87      2013.0         8.4
# 88      2014.0         8.7
# 89      2015.0         8.6
# 90      2016.0         9.1
#
# [91 rows x 2 columns]

# %%
(mov3.sort_values(by=['title_year', 'imdb_score'], ascending=[True, False])
 .drop_duplicates(subset='title_year', keep='first')
)
# Out:
#                                            movie_title  title_year  imdb_score
# 4695  Intolerance: Love's Struggle Throughout the Ages      1916.0         8.0
# 4833                    Over the Hill to the Poorhouse      1920.0         4.8
# 4767                                    The Big Parade      1925.0         8.3
# 2694                                        Metropolis      1927.0         8.3
# 4555                                     Pandora's Box      1929.0         8.0
# ...                                                ...         ...         ...
# 3                                The Dark Knight Rises      2012.0         8.5
# 3935           Batman: The Dark Knight Returns, Part 2      2013.0         8.4
# 4369                            Queen of the Mountains      2014.0         8.7
# 3745                                   Running Forever      2015.0         8.6
# 4312                              Kickboxer: Vengeance      2016.0         9.1
#
# [91 rows x 3 columns]

# %%
(mov3.groupby('title_year', as_index=False)
 .apply(lambda df: df.sort_values('imdb_score', ascending=False))
)
# Out:
#                                               movie_title  title_year  \
# 0  4695  Intolerance: Love's Struggle Throughout the Ages      1916.0
# 1  4833                    Over the Hill to the Poorhouse      1920.0
# 2  4767                                    The Big Parade      1925.0
# 3  2694                                        Metropolis      1927.0
# 4  4555                                     Pandora's Box      1929.0
# ...                                                   ...         ...
# 90 4658                               Fight to the Finish      2016.0
#    2431                                       Restoration      2016.0
#    4305                                       Cabin Fever      2016.0
#    3682                             Fifty Shades of Black      2016.0
#    4438                                  God's Not Dead 2      2016.0
#
#          imdb_score
# 0  4695         8.0
# 1  4833         4.8
# 2  4767         8.3
# 3  2694         8.3
# ...

# %%
(mov3.groupby('title_year', as_index=False)
 .apply(lambda df: df.sort_values('imdb_score', ascending=False).head(1))
 .droplevel(0, axis=0)
)
# Out:
#                                            movie_title  title_year  imdb_score
# 4695  Intolerance: Love's Struggle Throughout the Ages      1916.0         8.0
# 4833                    Over the Hill to the Poorhouse      1920.0         4.8
# 4767                                    The Big Parade      1925.0         8.3
# 2694                                        Metropolis      1927.0         8.3
# 4555                                     Pandora's Box      1929.0         8.0
# ...                                                ...         ...         ...
# 3                                The Dark Knight Rises      2012.0         8.5
# 3935           Batman: The Dark Knight Returns, Part 2      2013.0         8.4
# 4369                            Queen of the Mountains      2014.0         8.7
# 3745                                   Running Forever      2015.0         8.6
# 4312                              Kickboxer: Vengeance      2016.0         9.1
#
# [91 rows x 3 columns]
