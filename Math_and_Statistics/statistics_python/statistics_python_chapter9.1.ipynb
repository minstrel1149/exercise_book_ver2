# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as ss
import statsmodels.api as sm

# %%
np.random.seed(1);a = np.random.randint(0, 100, size=5)
np.random.seed(1);b = np.random.randint(0, 100, size=5)
a, b
# Out:
# (array([37, 12, 72,  9, 75]), array([37, 12, 72,  9, 75]))

# %%
m = [np.mean(np.random.randint(0, 100, size=50)) for i in range(100)]
m
# Out:
# [50.22,
#  43.88,
#  46.72,
#  52.1,
#  51.58,
#  54.66,
#  49.84,
#  46.44,
#  52.3,
#  53.16,
#  52.26,
#  53.04,
#  51.16,
#  52.78,
#  48.2,
#  51.04,
#  47.46,
#  55.5,
#  54.26,
#  43.02,
#  47.16,
#  52.54,
#  45.38,
#  54.52,
#  51.3,
#  47.76,
#  48.76,
#  50.76,
#  46.22,
#  52.24,
#  50.54,
#  49.26,
#  43.52,
#  45.82,
#  48.46,
#  49.84,
#  46.28,
#  50.1,
#  47.8,
#  47.0,
#  50.34,
#  47.6,
#  57.6,
#  49.4,
#  56.78,
#  50.94,
#  44.1,
#  47.18,
#  47.94,
#  49.28,
#  46.76,
#  52.96,
#  49.66,
#  48.18,
#  47.2,
#  49.84,
#  49.32,
#  43.34,
#  52.92,
#  48.14,
#  44.8,
#  51.96,
#  48.54,
#  44.88,
#  52.86,
#  55.8,
#  47.28,
#  46.74,
#  56.96,
#  52.16,
#  47.34,
#  51.96,
#  43.6,
#  43.7,
#  48.9,
#  51.56,
#  45.42,
#  57.44,
#  58.66,
#  50.82,
#  52.28,
#  48.32,
#  37.72,
#  51.0,
#  46.84,
#  44.68,
#  47.34,
#  43.24,
#  47.92,
#  54.04,
#  52.52,
#  47.24,
#  44.52,
#  49.62,
#  43.46,
#  41.42,
#  48.32,
#  43.64,
#  47.3,
#  48.38]

# %%
plt.hist(m, bins=7)
# Out:
# (array([ 1.,  9., 12., 35., 26., 11.,  6.]),
#  array([37.72      , 40.71142857, 43.70285714, 46.69428571, 49.68571429,
#         52.67714286, 55.66857143, 58.66      ]),
#  <BarContainer object of 7 artists>)

# %%
sm.qqplot(data=np.array(m), line='s')
