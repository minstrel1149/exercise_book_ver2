# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %%
target = torch.FloatTensor([i * 0.1 + 0.1 for i in range(9)]).reshape(3, 3)
target
# Out:
# tensor([[0.1000, 0.2000, 0.3000],
#         [0.4000, 0.5000, 0.6000],
#         [0.7000, 0.8000, 0.9000]])

# %%
x = torch.rand_like(target)
x.requires_grad = True
x
# Out:
# tensor([[0.1092, 0.2025, 0.4960],
#         [0.1093, 0.8525, 0.4141],
#         [0.1738, 0.8129, 0.3987]], requires_grad=True)

# %%
loss = F.mse_loss(x, target)
loss
# Out:
# tensor(0.0900, grad_fn=<MseLossBackward0>)

# %%
thres = 1e-5
lr = 0.1
iter_cnt = 0

# %%
while loss > thres:
    iter_cnt += 1
    loss.backward()
    x = x - lr*x.grad
    x.detach_()
    x.requires_grad_(True)
    loss = F.mse_loss(x, target)
    print(iter_cnt, loss)
    print(x)
# Out:
# 1 tensor(0.0861, grad_fn=<MseLossBackward0>)
# tensor([[0.1089, 0.2025, 0.4916],
#         [0.1158, 0.8446, 0.4182],
#         [0.1855, 0.8126, 0.4099]], requires_grad=True)
# 2 tensor(0.0823, grad_fn=<MseLossBackward0>)
# tensor([[0.1087, 0.2024, 0.4874],
#         [0.1221, 0.8370, 0.4222],
#         [0.1969, 0.8123, 0.4208]], requires_grad=True)
# 3 tensor(0.0787, grad_fn=<MseLossBackward0>)
# tensor([[0.1086, 0.2024, 0.4832],
#         [0.1283, 0.8295, 0.4262],
#         [0.2081, 0.8121, 0.4314]], requires_grad=True)
# 4 tensor(0.0752, grad_fn=<MseLossBackward0>)
# tensor([[0.1084, 0.2023, 0.4791],
#         [0.1343, 0.8222, 0.4301],
#         [0.2190, 0.8118, 0.4418]], requires_grad=True)
# 5 tensor(0.0719, grad_fn=<MseLossBackward0>)
# tensor([[0.1082, 0.2023, 0.4751],
#         [0.1402, 0.8150, 0.4338],
#         [0.2297, 0.8115, 0.4520]], requires_grad=True)
# 6 tensor(0.0687, grad_fn=<MseLossBackward0>)
# tensor([[0.1080, 0.2022, 0.4713],
#         [0.1460, 0.8080, 0.4375],
#         [0.2402, 0.8113, 0.4620]], requires_grad=True)
# 7 tensor(0.0657, grad_fn=<MseLossBackward0>)
# tensor([[0.1078, 0.2022, 0.4675],
#         [0.1516, 0.8011, 0.4411],
#         [0.2504, 0.8110, 0.4717]], requires_grad=True)
# 8 tensor(0.0628, grad_fn=<MseLossBackward0>)
# tensor([[0.1076, 0.2021, 0.4637],
#         [0.1571, 0.7945, 0.4447],
#         [0.2604, 0.8108, 0.4812]], requires_grad=True)
# 9 tensor(0.0601, grad_fn=<MseLossBackward0>)
# tensor([[0.1075, 0.2021, 0.4601],
#         [0.1625, 0.7879, 0.4481],
#         [0.2701, 0.8105, 0.4905]], requires_grad=True)
# 10 tensor(0.0574, grad_fn=<MseLossBackward0>)
# tensor([[0.1073, 0.2020, 0.4565],
#         [0.1678, 0.7815, 0.4515],
#         [0.2797, 0.8103, 0.4996]], requires_grad=True)
# 11 tensor(0.0549, grad_fn=<MseLossBackward0>)
# tensor([[0.1071, 0.2020, 0.4531],
#         [0.1730, 0.7753, 0.4548],
#         [0.2890, 0.8101, 0.5085]], requires_grad=True)
# 12 tensor(0.0525, grad_fn=<MseLossBackward0>)
# tensor([[0.1070, 0.2019, 0.4497],
#         [0.1780, 0.7691, 0.4580],
#         [0.2982, 0.8098, 0.5172]], requires_grad=True)
# 13 tensor(0.0502, grad_fn=<MseLossBackward0>)
# tensor([[0.1068, 0.2019, 0.4463],
#         [0.1829, 0.7632, 0.4612],
#         [0.3071, 0.8096, 0.5257]], requires_grad=True)
# 14 tensor(0.0480, grad_fn=<MseLossBackward0>)
# tensor([[0.1067, 0.2018, 0.4431],
#         [0.1878, 0.7573, 0.4643],
#         [0.3158, 0.8094, 0.5340]], requires_grad=True)
# 15 tensor(0.0459, grad_fn=<MseLossBackward0>)
# tensor([[0.1065, 0.2018, 0.4399],
#         [0.1925, 0.7516, 0.4673],
#         [0.3244, 0.8092, 0.5422]], requires_grad=True)
# 16 tensor(0.0439, grad_fn=<MseLossBackward0>)
# tensor([[0.1064, 0.2018, 0.4368],
#         [0.1971, 0.7460, 0.4702],
#         [0.3327, 0.8090, 0.5501]], requires_grad=True)
# 17 tensor(0.0419, grad_fn=<MseLossBackward0>)
# tensor([[0.1062, 0.2017, 0.4337],
#         [0.2016, 0.7405, 0.4731],
#         [0.3409, 0.8088, 0.5579]], requires_grad=True)
# 18 tensor(0.0401, grad_fn=<MseLossBackward0>)
# tensor([[0.1061, 0.2017, 0.4308],
#         [0.2060, 0.7352, 0.4759],
#         [0.3489, 0.8086, 0.5655]], requires_grad=True)
# 19 tensor(0.0383, grad_fn=<MseLossBackward0>)
# tensor([[0.1060, 0.2017, 0.4279],
#         [0.2103, 0.7300, 0.4787],
#         [0.3567, 0.8084, 0.5729]], requires_grad=True)
# 20 tensor(0.0366, grad_fn=<MseLossBackward0>)
# tensor([[0.1058, 0.2016, 0.4250],
#         [0.2145, 0.7249, 0.4814],
#         [0.3643, 0.8082, 0.5802]], requires_grad=True)
# 21 tensor(0.0350, grad_fn=<MseLossBackward0>)
# tensor([[0.1057, 0.2016, 0.4223],
#         [0.2187, 0.7199, 0.4840],
#         [0.3717, 0.8080, 0.5873]], requires_grad=True)
# 22 tensor(0.0335, grad_fn=<MseLossBackward0>)
# tensor([[0.1056, 0.2015, 0.4195],
#         [0.2227, 0.7150, 0.4866],
#         [0.3790, 0.8079, 0.5943]], requires_grad=True)
# 23 tensor(0.0320, grad_fn=<MseLossBackward0>)
# tensor([[0.1055, 0.2015, 0.4169],
#         [0.2266, 0.7102, 0.4891],
#         [0.3862, 0.8077, 0.6011]], requires_grad=True)
# 24 tensor(0.0306, grad_fn=<MseLossBackward0>)
# tensor([[0.1053, 0.2015, 0.4143],
#         [0.2305, 0.7055, 0.4916],
#         [0.3931, 0.8075, 0.6077]], requires_grad=True)
# 25 tensor(0.0293, grad_fn=<MseLossBackward0>)
# tensor([[0.1052, 0.2014, 0.4117],
#         [0.2343, 0.7010, 0.4940],
#         [0.4000, 0.8074, 0.6142]], requires_grad=True)
# 26 tensor(0.0280, grad_fn=<MseLossBackward0>)
# tensor([[0.1051, 0.2014, 0.4093],
#         [0.2379, 0.6965, 0.4963],
#         [0.4066, 0.8072, 0.6205]], requires_grad=True)
# 27 tensor(0.0267, grad_fn=<MseLossBackward0>)
# tensor([[0.1050, 0.2014, 0.4068],
#         [0.2415, 0.6921, 0.4987],
#         [0.4132, 0.8070, 0.6268]], requires_grad=True)
# 28 tensor(0.0256, grad_fn=<MseLossBackward0>)
# tensor([[0.1049, 0.2013, 0.4045],
#         [0.2451, 0.6879, 0.5009],
#         [0.4195, 0.8069, 0.6328]], requires_grad=True)
# 29 tensor(0.0244, grad_fn=<MseLossBackward0>)
# tensor([[0.1048, 0.2013, 0.4021],
#         [0.2485, 0.6837, 0.5031],
#         [0.4258, 0.8067, 0.6388]], requires_grad=True)
# 30 tensor(0.0234, grad_fn=<MseLossBackward0>)
# tensor([[0.1047, 0.2013, 0.3999],
#         [0.2519, 0.6796, 0.5053],
#         [0.4319, 0.8066, 0.6446]], requires_grad=True)
# 31 tensor(0.0223, grad_fn=<MseLossBackward0>)
# tensor([[0.1046, 0.2013, 0.3976],
#         [0.2552, 0.6756, 0.5074],
#         [0.4378, 0.8064, 0.6502]], requires_grad=True)
# 32 tensor(0.0214, grad_fn=<MseLossBackward0>)
# tensor([[0.1045, 0.2012, 0.3955],
#         [0.2584, 0.6717, 0.5094],
#         [0.4436, 0.8063, 0.6558]], requires_grad=True)
# 33 tensor(0.0204, grad_fn=<MseLossBackward0>)
# tensor([[0.1044, 0.2012, 0.3934],
#         [0.2615, 0.6679, 0.5114],
#         [0.4493, 0.8061, 0.6612]], requires_grad=True)
# 34 tensor(0.0195, grad_fn=<MseLossBackward0>)
# tensor([[0.1043, 0.2012, 0.3913],
#         [0.2646, 0.6642, 0.5134],
#         [0.4549, 0.8060, 0.6665]], requires_grad=True)
# 35 tensor(0.0187, grad_fn=<MseLossBackward0>)
# tensor([[0.1042, 0.2012, 0.3893],
#         [0.2676, 0.6605, 0.5153],
#         [0.4604, 0.8059, 0.6717]], requires_grad=True)
# 36 tensor(0.0178, grad_fn=<MseLossBackward0>)
# tensor([[0.1041, 0.2011, 0.3873],
#         [0.2706, 0.6569, 0.5172],
#         [0.4657, 0.8057, 0.6768]], requires_grad=True)
# 37 tensor(0.0171, grad_fn=<MseLossBackward0>)
# tensor([[0.1040, 0.2011, 0.3853],
#         [0.2734, 0.6535, 0.5191],
#         [0.4709, 0.8056, 0.6817]], requires_grad=True)
# 38 tensor(0.0163, grad_fn=<MseLossBackward0>)
# tensor([[0.1039, 0.2011, 0.3834],
#         [0.2762, 0.6500, 0.5208],
#         [0.4760, 0.8055, 0.6866]], requires_grad=True)
# 39 tensor(0.0156, grad_fn=<MseLossBackward0>)
# tensor([[0.1038, 0.2011, 0.3816],
#         [0.2790, 0.6467, 0.5226],
#         [0.4810, 0.8054, 0.6913]], requires_grad=True)
# 40 tensor(0.0149, grad_fn=<MseLossBackward0>)
# tensor([[0.1037, 0.2010, 0.3798],
#         [0.2817, 0.6435, 0.5243],
#         [0.4858, 0.8052, 0.6960]], requires_grad=True)
# 41 tensor(0.0143, grad_fn=<MseLossBackward0>)
# tensor([[0.1036, 0.2010, 0.3780],
#         [0.2843, 0.6403, 0.5260],
#         [0.4906, 0.8051, 0.7005]], requires_grad=True)
# 42 tensor(0.0136, grad_fn=<MseLossBackward0>)
# tensor([[0.1036, 0.2010, 0.3763],
#         [0.2869, 0.6371, 0.5277],
#         [0.4952, 0.8050, 0.7049]], requires_grad=True)
# 43 tensor(0.0130, grad_fn=<MseLossBackward0>)
# tensor([[0.1035, 0.2010, 0.3746],
#         [0.2894, 0.6341, 0.5293],
#         [0.4998, 0.8049, 0.7093]], requires_grad=True)
# 44 tensor(0.0125, grad_fn=<MseLossBackward0>)
# tensor([[0.1034, 0.2009, 0.3729],
#         [0.2919, 0.6311, 0.5308],
#         [0.5042, 0.8048, 0.7135]], requires_grad=True)
# 45 tensor(0.0119, grad_fn=<MseLossBackward0>)
# tensor([[0.1033, 0.2009, 0.3713],
#         [0.2943, 0.6282, 0.5324],
#         [0.5086, 0.8047, 0.7177]], requires_grad=True)
# 46 tensor(0.0114, grad_fn=<MseLossBackward0>)
# tensor([[0.1033, 0.2009, 0.3697],
#         [0.2966, 0.6254, 0.5339],
#         [0.5128, 0.8046, 0.7217]], requires_grad=True)
# 47 tensor(0.0109, grad_fn=<MseLossBackward0>)
# tensor([[0.1032, 0.2009, 0.3682],
#         [0.2989, 0.6226, 0.5353],
#         [0.5170, 0.8045, 0.7257]], requires_grad=True)
# 48 tensor(0.0104, grad_fn=<MseLossBackward0>)
# tensor([[0.1031, 0.2009, 0.3666],
#         [0.3012, 0.6198, 0.5368],
#         [0.5211, 0.8044, 0.7295]], requires_grad=True)
# 49 tensor(0.0100, grad_fn=<MseLossBackward0>)
# tensor([[0.1030, 0.2008, 0.3652],
#         [0.3033, 0.6172, 0.5382],
#         [0.5250, 0.8043, 0.7333]], requires_grad=True)
# 50 tensor(0.0095, grad_fn=<MseLossBackward0>)
# tensor([[0.1030, 0.2008, 0.3637],
#         [0.3055, 0.6146, 0.5396],
#         [0.5289, 0.8042, 0.7370]], requires_grad=True)
# 51 tensor(0.0091, grad_fn=<MseLossBackward0>)
# tensor([[0.1029, 0.2008, 0.3623],
#         [0.3076, 0.6120, 0.5409],
#         [0.5327, 0.8041, 0.7407]], requires_grad=True)
# 52 tensor(0.0087, grad_fn=<MseLossBackward0>)
# tensor([[0.1028, 0.2008, 0.3609],
#         [0.3096, 0.6095, 0.5422],
#         [0.5364, 0.8040, 0.7442]], requires_grad=True)
# 53 tensor(0.0083, grad_fn=<MseLossBackward0>)
# tensor([[0.1028, 0.2008, 0.3596],
#         [0.3117, 0.6071, 0.5435],
#         [0.5401, 0.8039, 0.7477]], requires_grad=True)
# 54 tensor(0.0079, grad_fn=<MseLossBackward0>)
# tensor([[0.1027, 0.2008, 0.3582],
#         [0.3136, 0.6047, 0.5448],
#         [0.5436, 0.8038, 0.7511]], requires_grad=True)
# 55 tensor(0.0076, grad_fn=<MseLossBackward0>)
# tensor([[0.1027, 0.2007, 0.3569],
#         [0.3155, 0.6024, 0.5460],
#         [0.5471, 0.8037, 0.7544]], requires_grad=True)
# 56 tensor(0.0073, grad_fn=<MseLossBackward0>)
# tensor([[0.1026, 0.2007, 0.3557],
#         [0.3174, 0.6001, 0.5472],
#         [0.5505, 0.8037, 0.7576]], requires_grad=True)
# 57 tensor(0.0069, grad_fn=<MseLossBackward0>)
# tensor([[0.1025, 0.2007, 0.3544],
#         [0.3193, 0.5979, 0.5484],
#         [0.5538, 0.8036, 0.7608]], requires_grad=True)
# 58 tensor(0.0066, grad_fn=<MseLossBackward0>)
# tensor([[0.1025, 0.2007, 0.3532],
#         [0.3210, 0.5957, 0.5495],
#         [0.5571, 0.8035, 0.7639]], requires_grad=True)
# 59 tensor(0.0063, grad_fn=<MseLossBackward0>)
# tensor([[0.1024, 0.2007, 0.3520],
#         [0.3228, 0.5936, 0.5506],
#         [0.5603, 0.8034, 0.7669]], requires_grad=True)
# 60 tensor(0.0061, grad_fn=<MseLossBackward0>)
# tensor([[0.1024, 0.2007, 0.3509],
#         [0.3245, 0.5915, 0.5517],
#         [0.5634, 0.8033, 0.7698]], requires_grad=True)
# 61 tensor(0.0058, grad_fn=<MseLossBackward0>)
# tensor([[0.1023, 0.2006, 0.3498],
#         [0.3262, 0.5895, 0.5528],
#         [0.5664, 0.8033, 0.7727]], requires_grad=True)
# 62 tensor(0.0055, grad_fn=<MseLossBackward0>)
# tensor([[0.1023, 0.2006, 0.3487],
#         [0.3278, 0.5875, 0.5538],
#         [0.5694, 0.8032, 0.7756]], requires_grad=True)
# 63 tensor(0.0053, grad_fn=<MseLossBackward0>)
# tensor([[0.1022, 0.2006, 0.3476],
#         [0.3294, 0.5856, 0.5549],
#         [0.5723, 0.8031, 0.7783]], requires_grad=True)
# 64 tensor(0.0051, grad_fn=<MseLossBackward0>)
# tensor([[0.1022, 0.2006, 0.3465],
#         [0.3310, 0.5837, 0.5559],
#         [0.5751, 0.8031, 0.7810]], requires_grad=True)
# 65 tensor(0.0048, grad_fn=<MseLossBackward0>)
# tensor([[0.1021, 0.2006, 0.3455],
#         [0.3325, 0.5818, 0.5569],
#         [0.5779, 0.8030, 0.7837]], requires_grad=True)
# 66 tensor(0.0046, grad_fn=<MseLossBackward0>)
# tensor([[0.1021, 0.2006, 0.3445],
#         [0.3340, 0.5800, 0.5578],
#         [0.5806, 0.8029, 0.7863]], requires_grad=True)
# 67 tensor(0.0044, grad_fn=<MseLossBackward0>)
# tensor([[0.1020, 0.2006, 0.3435],
#         [0.3355, 0.5782, 0.5588],
#         [0.5833, 0.8029, 0.7888]], requires_grad=True)
# 68 tensor(0.0042, grad_fn=<MseLossBackward0>)
# tensor([[0.1020, 0.2005, 0.3425],
#         [0.3369, 0.5765, 0.5597],
#         [0.5858, 0.8028, 0.7913]], requires_grad=True)
# 69 tensor(0.0041, grad_fn=<MseLossBackward0>)
# tensor([[0.1019, 0.2005, 0.3416],
#         [0.3383, 0.5748, 0.5606],
#         [0.5884, 0.8027, 0.7937]], requires_grad=True)
# 70 tensor(0.0039, grad_fn=<MseLossBackward0>)
# tensor([[0.1019, 0.2005, 0.3406],
#         [0.3397, 0.5731, 0.5614],
#         [0.5909, 0.8027, 0.7960]], requires_grad=True)
# 71 tensor(0.0037, grad_fn=<MseLossBackward0>)
# tensor([[0.1019, 0.2005, 0.3397],
#         [0.3410, 0.5715, 0.5623],
#         [0.5933, 0.8026, 0.7983]], requires_grad=True)
# 72 tensor(0.0035, grad_fn=<MseLossBackward0>)
# tensor([[0.1018, 0.2005, 0.3389],
#         [0.3424, 0.5699, 0.5631],
#         [0.5957, 0.8026, 0.8006]], requires_grad=True)
# 73 tensor(0.0034, grad_fn=<MseLossBackward0>)
# tensor([[0.1018, 0.2005, 0.3380],
#         [0.3436, 0.5683, 0.5640],
#         [0.5980, 0.8025, 0.8028]], requires_grad=True)
# 74 tensor(0.0032, grad_fn=<MseLossBackward0>)
# tensor([[0.1017, 0.2005, 0.3372],
#         [0.3449, 0.5668, 0.5648],
#         [0.6002, 0.8024, 0.8050]], requires_grad=True)
# 75 tensor(0.0031, grad_fn=<MseLossBackward0>)
# tensor([[0.1017, 0.2005, 0.3363],
#         [0.3461, 0.5653, 0.5655],
#         [0.6025, 0.8024, 0.8071]], requires_grad=True)
# 76 tensor(0.0030, grad_fn=<MseLossBackward0>)
# tensor([[0.1017, 0.2005, 0.3355],
#         [0.3473, 0.5639, 0.5663],
#         [0.6046, 0.8023, 0.8092]], requires_grad=True)
# 77 tensor(0.0028, grad_fn=<MseLossBackward0>)
# tensor([[0.1016, 0.2004, 0.3347],
#         [0.3485, 0.5625, 0.5671],
#         [0.6067, 0.8023, 0.8112]], requires_grad=True)
# 78 tensor(0.0027, grad_fn=<MseLossBackward0>)
# tensor([[0.1016, 0.2004, 0.3340],
#         [0.3496, 0.5611, 0.5678],
#         [0.6088, 0.8022, 0.8131]], requires_grad=True)
# 79 tensor(0.0026, grad_fn=<MseLossBackward0>)
# tensor([[0.1016, 0.2004, 0.3332],
#         [0.3507, 0.5597, 0.5685],
#         [0.6108, 0.8022, 0.8151]], requires_grad=True)
# 80 tensor(0.0025, grad_fn=<MseLossBackward0>)
# tensor([[0.1015, 0.2004, 0.3325],
#         [0.3518, 0.5584, 0.5692],
#         [0.6128, 0.8021, 0.8170]], requires_grad=True)
# 81 tensor(0.0024, grad_fn=<MseLossBackward0>)
# tensor([[0.1015, 0.2004, 0.3317],
#         [0.3529, 0.5571, 0.5699],
#         [0.6148, 0.8021, 0.8188]], requires_grad=True)
# 82 tensor(0.0023, grad_fn=<MseLossBackward0>)
# tensor([[0.1014, 0.2004, 0.3310],
#         [0.3540, 0.5558, 0.5706],
#         [0.6167, 0.8020, 0.8206]], requires_grad=True)
# 83 tensor(0.0022, grad_fn=<MseLossBackward0>)
# tensor([[0.1014, 0.2004, 0.3303],
#         [0.3550, 0.5546, 0.5712],
#         [0.6185, 0.8020, 0.8224]], requires_grad=True)
# 84 tensor(0.0021, grad_fn=<MseLossBackward0>)
# tensor([[0.1014, 0.2004, 0.3297],
#         [0.3560, 0.5534, 0.5718],
#         [0.6203, 0.8020, 0.8241]], requires_grad=True)
# 85 tensor(0.0020, grad_fn=<MseLossBackward0>)
# tensor([[0.1014, 0.2004, 0.3290],
#         [0.3570, 0.5522, 0.5725],
#         [0.6221, 0.8019, 0.8258]], requires_grad=True)
# 86 tensor(0.0019, grad_fn=<MseLossBackward0>)
# tensor([[0.1013, 0.2004, 0.3284],
#         [0.3579, 0.5510, 0.5731],
#         [0.6238, 0.8019, 0.8274]], requires_grad=True)
# 87 tensor(0.0018, grad_fn=<MseLossBackward0>)
# tensor([[0.1013, 0.2004, 0.3277],
#         [0.3589, 0.5499, 0.5737],
#         [0.6255, 0.8018, 0.8290]], requires_grad=True)
# 88 tensor(0.0017, grad_fn=<MseLossBackward0>)
# tensor([[0.1013, 0.2004, 0.3271],
#         [0.3598, 0.5488, 0.5743],
#         [0.6272, 0.8018, 0.8306]], requires_grad=True)
# 89 tensor(0.0016, grad_fn=<MseLossBackward0>)
# tensor([[0.1012, 0.2003, 0.3265],
#         [0.3607, 0.5477, 0.5748],
#         [0.6288, 0.8017, 0.8322]], requires_grad=True)
# 90 tensor(0.0016, grad_fn=<MseLossBackward0>)
# tensor([[0.1012, 0.2003, 0.3259],
#         [0.3615, 0.5466, 0.5754],
#         [0.6304, 0.8017, 0.8337]], requires_grad=True)
# 91 tensor(0.0015, grad_fn=<MseLossBackward0>)
# tensor([[0.1012, 0.2003, 0.3254],
#         [0.3624, 0.5456, 0.5759],
#         [0.6319, 0.8017, 0.8351]], requires_grad=True)
# 92 tensor(0.0014, grad_fn=<MseLossBackward0>)
# tensor([[0.1012, 0.2003, 0.3248],
#         [0.3632, 0.5446, 0.5765],
#         [0.6334, 0.8016, 0.8366]], requires_grad=True)
# 93 tensor(0.0014, grad_fn=<MseLossBackward0>)
# tensor([[0.1011, 0.2003, 0.3242],
#         [0.3640, 0.5436, 0.5770],
#         [0.6349, 0.8016, 0.8380]], requires_grad=True)
# 94 tensor(0.0013, grad_fn=<MseLossBackward0>)
# tensor([[0.1011, 0.2003, 0.3237],
#         [0.3648, 0.5426, 0.5775],
#         [0.6364, 0.8016, 0.8394]], requires_grad=True)
# 95 tensor(0.0013, grad_fn=<MseLossBackward0>)
# tensor([[0.1011, 0.2003, 0.3232],
#         [0.3656, 0.5417, 0.5780],
#         [0.6378, 0.8015, 0.8407]], requires_grad=True)
# 96 tensor(0.0012, grad_fn=<MseLossBackward0>)
# tensor([[0.1011, 0.2003, 0.3227],
#         [0.3664, 0.5408, 0.5785],
#         [0.6392, 0.8015, 0.8420]], requires_grad=True)
# 97 tensor(0.0012, grad_fn=<MseLossBackward0>)
# tensor([[0.1010, 0.2003, 0.3222],
#         [0.3671, 0.5398, 0.5790],
#         [0.6405, 0.8015, 0.8433]], requires_grad=True)
# 98 tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor([[0.1010, 0.2003, 0.3217],
#         [0.3679, 0.5390, 0.5794],
#         [0.6418, 0.8014, 0.8446]], requires_grad=True)
# 99 tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor([[0.1010, 0.2003, 0.3212],
#         [0.3686, 0.5381, 0.5799],
#         [0.6431, 0.8014, 0.8458]], requires_grad=True)
# 100 tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor([[0.1010, 0.2003, 0.3207],
#         [0.3693, 0.5372, 0.5804],
#         [0.6444, 0.8014, 0.8470]], requires_grad=True)
# 101 tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor([[0.1009, 0.2003, 0.3203],
#         [0.3700, 0.5364, 0.5808],
#         [0.6456, 0.8013, 0.8482]], requires_grad=True)
# 102 tensor(0.0009, grad_fn=<MseLossBackward0>)
# tensor([[0.1009, 0.2003, 0.3198],
#         [0.3706, 0.5356, 0.5812],
#         [0.6468, 0.8013, 0.8494]], requires_grad=True)
# 103 tensor(0.0009, grad_fn=<MseLossBackward0>)
# tensor([[0.1009, 0.2002, 0.3194],
#         [0.3713, 0.5348, 0.5816],
#         [0.6480, 0.8013, 0.8505]], requires_grad=True)
# 104 tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor([[0.1009, 0.2002, 0.3189],
#         [0.3719, 0.5340, 0.5820],
#         [0.6492, 0.8012, 0.8516]], requires_grad=True)
# 105 tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor([[0.1009, 0.2002, 0.3185],
#         [0.3725, 0.5333, 0.5824],
#         [0.6503, 0.8012, 0.8527]], requires_grad=True)
# 106 tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor([[0.1008, 0.2002, 0.3181],
#         [0.3732, 0.5326, 0.5828],
#         [0.6514, 0.8012, 0.8537]], requires_grad=True)
# 107 tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor([[0.1008, 0.2002, 0.3177],
#         [0.3737, 0.5318, 0.5832],
#         [0.6525, 0.8012, 0.8547]], requires_grad=True)
# 108 tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor([[0.1008, 0.2002, 0.3173],
#         [0.3743, 0.5311, 0.5836],
#         [0.6535, 0.8011, 0.8557]], requires_grad=True)
# 109 tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor([[0.1008, 0.2002, 0.3169],
#         [0.3749, 0.5304, 0.5839],
#         [0.6546, 0.8011, 0.8567]], requires_grad=True)
# 110 tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor([[0.1008, 0.2002, 0.3165],
#         [0.3755, 0.5298, 0.5843],
#         [0.6556, 0.8011, 0.8577]], requires_grad=True)
# 111 tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor([[0.1008, 0.2002, 0.3162],
#         [0.3760, 0.5291, 0.5847],
#         [0.6566, 0.8011, 0.8586]], requires_grad=True)
# 112 tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor([[0.1007, 0.2002, 0.3158],
#         [0.3765, 0.5284, 0.5850],
#         [0.6575, 0.8010, 0.8595]], requires_grad=True)
# 113 tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor([[0.1007, 0.2002, 0.3155],
#         [0.3771, 0.5278, 0.5853],
#         [0.6585, 0.8010, 0.8604]], requires_grad=True)
# 114 tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor([[0.1007, 0.2002, 0.3151],
#         [0.3776, 0.5272, 0.5857],
#         [0.6594, 0.8010, 0.8613]], requires_grad=True)
# 115 tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor([[0.1007, 0.2002, 0.3148],
#         [0.3781, 0.5266, 0.5860],
#         [0.6603, 0.8010, 0.8622]], requires_grad=True)
# 116 tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor([[0.1007, 0.2002, 0.3145],
#         [0.3786, 0.5260, 0.5863],
#         [0.6612, 0.8010, 0.8630]], requires_grad=True)
# 117 tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor([[0.1007, 0.2002, 0.3141],
#         [0.3790, 0.5254, 0.5866],
#         [0.6620, 0.8009, 0.8638]], requires_grad=True)
# 118 tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1006, 0.2002, 0.3138],
#         [0.3795, 0.5249, 0.5869],
#         [0.6629, 0.8009, 0.8646]], requires_grad=True)
# 119 tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1006, 0.2002, 0.3135],
#         [0.3800, 0.5243, 0.5872],
#         [0.6637, 0.8009, 0.8654]], requires_grad=True)
# 120 tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1006, 0.2002, 0.3132],
#         [0.3804, 0.5238, 0.5875],
#         [0.6645, 0.8009, 0.8662]], requires_grad=True)
# 121 tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1006, 0.2002, 0.3129],
#         [0.3808, 0.5232, 0.5877],
#         [0.6653, 0.8008, 0.8670]], requires_grad=True)
# 122 tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1006, 0.2002, 0.3126],
#         [0.3813, 0.5227, 0.5880],
#         [0.6661, 0.8008, 0.8677]], requires_grad=True)
# 123 tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1006, 0.2002, 0.3124],
#         [0.3817, 0.5222, 0.5883],
#         [0.6668, 0.8008, 0.8684]], requires_grad=True)
# 124 tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1006, 0.2002, 0.3121],
#         [0.3821, 0.5217, 0.5885],
#         [0.6676, 0.8008, 0.8691]], requires_grad=True)
# 125 tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1006, 0.2002, 0.3118],
#         [0.3825, 0.5212, 0.5888],
#         [0.6683, 0.8008, 0.8698]], requires_grad=True)
# 126 tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3115],
#         [0.3829, 0.5208, 0.5890],
#         [0.6690, 0.8008, 0.8705]], requires_grad=True)
# 127 tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3113],
#         [0.3833, 0.5203, 0.5893],
#         [0.6697, 0.8007, 0.8711]], requires_grad=True)
# 128 tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3110],
#         [0.3836, 0.5199, 0.5895],
#         [0.6704, 0.8007, 0.8718]], requires_grad=True)
# 129 tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3108],
#         [0.3840, 0.5194, 0.5898],
#         [0.6710, 0.8007, 0.8724]], requires_grad=True)
# 130 tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3106],
#         [0.3843, 0.5190, 0.5900],
#         [0.6717, 0.8007, 0.8730]], requires_grad=True)
# 131 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3103],
#         [0.3847, 0.5186, 0.5902],
#         [0.6723, 0.8007, 0.8736]], requires_grad=True)
# 132 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3101],
#         [0.3850, 0.5181, 0.5904],
#         [0.6729, 0.8007, 0.8742]], requires_grad=True)
# 133 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3099],
#         [0.3854, 0.5177, 0.5906],
#         [0.6735, 0.8006, 0.8748]], requires_grad=True)
# 134 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1005, 0.2001, 0.3096],
#         [0.3857, 0.5173, 0.5908],
#         [0.6741, 0.8006, 0.8753]], requires_grad=True)
# 135 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3094],
#         [0.3860, 0.5170, 0.5911],
#         [0.6747, 0.8006, 0.8759]], requires_grad=True)
# 136 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3092],
#         [0.3863, 0.5166, 0.5913],
#         [0.6752, 0.8006, 0.8764]], requires_grad=True)
# 137 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3090],
#         [0.3866, 0.5162, 0.5914],
#         [0.6758, 0.8006, 0.8769]], requires_grad=True)
# 138 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3088],
#         [0.3869, 0.5159, 0.5916],
#         [0.6763, 0.8006, 0.8774]], requires_grad=True)
# 139 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3086],
#         [0.3872, 0.5155, 0.5918],
#         [0.6769, 0.8006, 0.8779]], requires_grad=True)
# 140 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3084],
#         [0.3875, 0.5152, 0.5920],
#         [0.6774, 0.8006, 0.8784]], requires_grad=True)
# 141 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3082],
#         [0.3878, 0.5148, 0.5922],
#         [0.6779, 0.8005, 0.8789]], requires_grad=True)
# 142 tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3081],
#         [0.3880, 0.5145, 0.5924],
#         [0.6784, 0.8005, 0.8794]], requires_grad=True)
# 143 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3079],
#         [0.3883, 0.5142, 0.5925],
#         [0.6788, 0.8005, 0.8798]], requires_grad=True)
# 144 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3077],
#         [0.3886, 0.5139, 0.5927],
#         [0.6793, 0.8005, 0.8803]], requires_grad=True)
# 145 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1004, 0.2001, 0.3075],
#         [0.3888, 0.5135, 0.5929],
#         [0.6798, 0.8005, 0.8807]], requires_grad=True)
# 146 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3074],
#         [0.3891, 0.5132, 0.5930],
#         [0.6802, 0.8005, 0.8812]], requires_grad=True)
# 147 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3072],
#         [0.3893, 0.5130, 0.5932],
#         [0.6807, 0.8005, 0.8816]], requires_grad=True)
# 148 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3070],
#         [0.3896, 0.5127, 0.5933],
#         [0.6811, 0.8005, 0.8820]], requires_grad=True)
# 149 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3069],
#         [0.3898, 0.5124, 0.5935],
#         [0.6815, 0.8005, 0.8824]], requires_grad=True)
# 150 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3067],
#         [0.3900, 0.5121, 0.5936],
#         [0.6819, 0.8004, 0.8828]], requires_grad=True)
# 151 tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3066],
#         [0.3902, 0.5118, 0.5938],
#         [0.6823, 0.8004, 0.8832]], requires_grad=True)
# 152 tensor(9.7123e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3064],
#         [0.3905, 0.5116, 0.5939],
#         [0.6827, 0.8004, 0.8835]], requires_grad=True)
# 153 tensor(9.2854e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3063],
#         [0.3907, 0.5113, 0.5940],
#         [0.6831, 0.8004, 0.8839]], requires_grad=True)
# 154 tensor(8.8773e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3062],
#         [0.3909, 0.5111, 0.5942],
#         [0.6835, 0.8004, 0.8843]], requires_grad=True)
# 155 tensor(8.4872e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3060],
#         [0.3911, 0.5108, 0.5943],
#         [0.6838, 0.8004, 0.8846]], requires_grad=True)
# 156 tensor(8.1142e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3059],
#         [0.3913, 0.5106, 0.5944],
#         [0.6842, 0.8004, 0.8849]], requires_grad=True)
# 157 tensor(7.7575e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3058],
#         [0.3915, 0.5103, 0.5945],
#         [0.6846, 0.8004, 0.8853]], requires_grad=True)
# 158 tensor(7.4166e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3056],
#         [0.3917, 0.5101, 0.5947],
#         [0.6849, 0.8004, 0.8856]], requires_grad=True)
# 159 tensor(7.0907e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3055],
#         [0.3918, 0.5099, 0.5948],
#         [0.6852, 0.8004, 0.8859]], requires_grad=True)
# 160 tensor(6.7790e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1003, 0.2001, 0.3054],
#         [0.3920, 0.5097, 0.5949],
#         [0.6856, 0.8004, 0.8862]], requires_grad=True)
# 161 tensor(6.4811e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3053],
#         [0.3922, 0.5095, 0.5950],
#         [0.6859, 0.8003, 0.8865]], requires_grad=True)
# 162 tensor(6.1962e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3051],
#         [0.3924, 0.5092, 0.5951],
#         [0.6862, 0.8003, 0.8868]], requires_grad=True)
# 163 tensor(5.9239e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3050],
#         [0.3925, 0.5090, 0.5952],
#         [0.6865, 0.8003, 0.8871]], requires_grad=True)
# 164 tensor(5.6636e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3049],
#         [0.3927, 0.5088, 0.5953],
#         [0.6868, 0.8003, 0.8874]], requires_grad=True)
# 165 tensor(5.4146e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3048],
#         [0.3929, 0.5086, 0.5954],
#         [0.6871, 0.8003, 0.8877]], requires_grad=True)
# 166 tensor(5.1766e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3047],
#         [0.3930, 0.5085, 0.5955],
#         [0.6874, 0.8003, 0.8880]], requires_grad=True)
# 167 tensor(4.9491e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3046],
#         [0.3932, 0.5083, 0.5956],
#         [0.6877, 0.8003, 0.8882]], requires_grad=True)
# 168 tensor(4.7316e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3045],
#         [0.3933, 0.5081, 0.5957],
#         [0.6879, 0.8003, 0.8885]], requires_grad=True)
# 169 tensor(4.5237e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3044],
#         [0.3935, 0.5079, 0.5958],
#         [0.6882, 0.8003, 0.8888]], requires_grad=True)
# 170 tensor(4.3248e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3043],
#         [0.3936, 0.5077, 0.5959],
#         [0.6885, 0.8003, 0.8890]], requires_grad=True)
# 171 tensor(4.1348e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3042],
#         [0.3938, 0.5076, 0.5960],
#         [0.6887, 0.8003, 0.8893]], requires_grad=True)
# 172 tensor(3.9530e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3041],
#         [0.3939, 0.5074, 0.5961],
#         [0.6890, 0.8003, 0.8895]], requires_grad=True)
# 173 tensor(3.7793e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3040],
#         [0.3940, 0.5072, 0.5962],
#         [0.6892, 0.8003, 0.8897]], requires_grad=True)
# 174 tensor(3.6132e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2001, 0.3039],
#         [0.3942, 0.5071, 0.5963],
#         [0.6895, 0.8003, 0.8900]], requires_grad=True)
# 175 tensor(3.4544e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2000, 0.3038],
#         [0.3943, 0.5069, 0.5964],
#         [0.6897, 0.8003, 0.8902]], requires_grad=True)
# 176 tensor(3.3026e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2000, 0.3038],
#         [0.3944, 0.5068, 0.5964],
#         [0.6899, 0.8002, 0.8904]], requires_grad=True)
# 177 tensor(3.1574e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2000, 0.3037],
#         [0.3946, 0.5066, 0.5965],
#         [0.6901, 0.8002, 0.8906]], requires_grad=True)
# 178 tensor(3.0187e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2000, 0.3036],
#         [0.3947, 0.5065, 0.5966],
#         [0.6904, 0.8002, 0.8908]], requires_grad=True)
# 179 tensor(2.8860e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2000, 0.3035],
#         [0.3948, 0.5063, 0.5967],
#         [0.6906, 0.8002, 0.8910]], requires_grad=True)
# 180 tensor(2.7592e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2000, 0.3034],
#         [0.3949, 0.5062, 0.5967],
#         [0.6908, 0.8002, 0.8912]], requires_grad=True)
# 181 tensor(2.6379e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2000, 0.3034],
#         [0.3950, 0.5060, 0.5968],
#         [0.6910, 0.8002, 0.8914]], requires_grad=True)
# 182 tensor(2.5220e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1002, 0.2000, 0.3033],
#         [0.3951, 0.5059, 0.5969],
#         [0.6912, 0.8002, 0.8916]], requires_grad=True)
# 183 tensor(2.4111e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3032],
#         [0.3952, 0.5058, 0.5970],
#         [0.6914, 0.8002, 0.8918]], requires_grad=True)
# 184 tensor(2.3051e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3031],
#         [0.3953, 0.5056, 0.5970],
#         [0.6916, 0.8002, 0.8920]], requires_grad=True)
# 185 tensor(2.2038e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3031],
#         [0.3955, 0.5055, 0.5971],
#         [0.6918, 0.8002, 0.8922]], requires_grad=True)
# 186 tensor(2.1070e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3030],
#         [0.3956, 0.5054, 0.5972],
#         [0.6919, 0.8002, 0.8923]], requires_grad=True)
# 187 tensor(2.0144e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3029],
#         [0.3957, 0.5053, 0.5972],
#         [0.6921, 0.8002, 0.8925]], requires_grad=True)
# 188 tensor(1.9258e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3029],
#         [0.3957, 0.5052, 0.5973],
#         [0.6923, 0.8002, 0.8927]], requires_grad=True)
# 189 tensor(1.8412e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3028],
#         [0.3958, 0.5050, 0.5973],
#         [0.6925, 0.8002, 0.8928]], requires_grad=True)
# 190 tensor(1.7603e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3027],
#         [0.3959, 0.5049, 0.5974],
#         [0.6926, 0.8002, 0.8930]], requires_grad=True)
# 191 tensor(1.6829e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3027],
#         [0.3960, 0.5048, 0.5975],
#         [0.6928, 0.8002, 0.8931]], requires_grad=True)
# 192 tensor(1.6089e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3026],
#         [0.3961, 0.5047, 0.5975],
#         [0.6930, 0.8002, 0.8933]], requires_grad=True)
# 193 tensor(1.5382e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3026],
#         [0.3962, 0.5046, 0.5976],
#         [0.6931, 0.8002, 0.8934]], requires_grad=True)
# 194 tensor(1.4706e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3025],
#         [0.3963, 0.5045, 0.5976],
#         [0.6933, 0.8002, 0.8936]], requires_grad=True)
# 195 tensor(1.4060e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3024],
#         [0.3964, 0.5044, 0.5977],
#         [0.6934, 0.8002, 0.8937]], requires_grad=True)
# 196 tensor(1.3442e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3024],
#         [0.3964, 0.5043, 0.5977],
#         [0.6936, 0.8002, 0.8939]], requires_grad=True)
# 197 tensor(1.2851e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3023],
#         [0.3965, 0.5042, 0.5978],
#         [0.6937, 0.8002, 0.8940]], requires_grad=True)
# 198 tensor(1.2286e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3023],
#         [0.3966, 0.5041, 0.5978],
#         [0.6939, 0.8002, 0.8941]], requires_grad=True)
# 199 tensor(1.1746e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3022],
#         [0.3967, 0.5040, 0.5979],
#         [0.6940, 0.8001, 0.8943]], requires_grad=True)
# 200 tensor(1.1230e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3022],
#         [0.3968, 0.5039, 0.5979],
#         [0.6941, 0.8001, 0.8944]], requires_grad=True)
# 201 tensor(1.0736e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3021],
#         [0.3968, 0.5038, 0.5980],
#         [0.6943, 0.8001, 0.8945]], requires_grad=True)
# 202 tensor(1.0265e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3021],
#         [0.3969, 0.5038, 0.5980],
#         [0.6944, 0.8001, 0.8946]], requires_grad=True)
# 203 tensor(9.8134e-06, grad_fn=<MseLossBackward0>)
# tensor([[0.1001, 0.2000, 0.3020],
#         [0.3970, 0.5037, 0.5981],
#         [0.6945, 0.8001, 0.8948]], requires_grad=True)

# %%
x = torch.FloatTensor([[1, 2],
                       [3, 4]]).requires_grad_(True)
x
# Out:
# tensor([[1., 2.],
#         [3., 4.]], requires_grad=True)
