# %%
import os
import numpy as np
import pandas as pd
from copy import deepcopy
from typing import List, Tuple, Dict, Callable
import tensorflow as tf
import tensorflow.keras as keras
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from alibi.explainers import CounterfactualRLTabular, CounterfactualRL
from alibi.datasets import fetch_adult
from alibi.explainers.backends.cfrl_tabular import get_he_preprocessor, apply_category_mapping
# Out:
# C:\Users\user\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
 # Fetch adult dataset
adult = fetch_adult()
# Separate columns in numerical and categorical.
categorical_names = [adult.feature_names[i] for i in adult.category_map.keys()]
categorical_ids = list(adult.category_map.keys())
numerical_names = [name for i, name in enumerate(adult.feature_names) if i not in adult.category_map.keys()]
numerical_ids = [i for i in range(len(adult.feature_names)) if i not in adult.category_map.keys()]

# Split data into train and test
X, Y = adult.data, adult.target
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=13)
print(X_train[:5])
# Out:
# [[46  4  4  0  6  0  2  1  0  0 60  9]
#  [28  4  4  1  2  4  4  0  0  0 40  5]
#  [19  0  4  1  0  3  4  0  0  0 35  9]
#  [43  4  4  1  2  3  4  1  0  0 40  9]
#  [22  0  4  1  0  3  4  1  0  0 35  9]]

# %%
preprocessor = ColumnTransformer([("num", StandardScaler(), numerical_ids), 
                                  ("cat", OneHotEncoder(sparse=False, handle_unknown="ignore"),
                                   categorical_ids)])

# %%
preprocessor.fit(X_train)
# Preprocess train and test dataset.
X_train_ohe = preprocessor.transform(X_train)
X_test_ohe = preprocessor.transform(X_test)

# %%
# Select one of the below classifiers.
# clf = XGBClassifier(min_child_weight=0.5, max_depth=3, gamma=0.2)
# clf = LogisticRegression(C=10)
# clf = DecisionTreeClassifier(max_depth=10, min_samples_split=5)
clf = RandomForestClassifier(max_depth=15, min_samples_split=10, n_estimators=50)
# Fit the classifier.
clf.fit(X_train_ohe, Y_train)
# Out:
# RandomForestClassifier(max_depth=15, min_samples_split=10, n_estimators=50)

# %%
# Define prediction function.
predictor = lambda x: clf.predict_proba(preprocessor.transform(x))

# %%
acc = accuracy_score(y_true=Y_test, y_pred=predictor(X_test).argmax(axis=1))
print("Accuracy: %.3f" % acc)
# Out:
# Accuracy: 0.862

# %%
class ADULTEncoder(keras.Model):
    def __init__(self, hidden_dim: int, latent_dim: int, **kwargs):
        super().__init__(**kwargs)
        self.fc1 = keras.layers.Dense(hidden_dim)
        self.fc2 = keras.layers.Dense(latent_dim)
    
    def call(self, x: tf.Tensor, **kwargs) -> tf.Tensor:
        x = tf.nn.relu(self.fc1(x))
        x = tf.nn.tanh(self.fc2(x))
        return x

# %%
class ADULTDecoder(keras.Model):
    
    def __init__(self, hidden_dim: int, output_dims: List[int], **kwargs):
        
        super().__init__(**kwargs)

        self.fc1 = keras.layers.Dense(hidden_dim)
        self.fcs = [keras.layers.Dense(dim) for dim in output_dims]


    def call(self, x: tf.Tensor, **kwargs) -> List[tf.Tensor]:
        x = tf.nn.relu(self.fc1(x))
        xs = [fc(x) for fc in self.fcs]
        return xs

# %%
class HeAE(keras.Model):
    def __init__(self, encoder: keras.Model, decoder: keras.Model, **kwargs) -> None:
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
    def call(self, x: tf.Tensor, **kwargs):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return x_hat

# %%
# Define attribute types, required for datatype conversion.
feature_types = {"Age": int, "Capital Gain": int, "Capital Loss": int, "Hours per week":int}

heae_preprocessor, heae_inv_preprocessor = get_he_preprocessor(X=X_train, feature_names=adult.feature_names,
                                          category_map=adult.category_map,feature_types=feature_types)
# Define trainset
trainset_input = heae_preprocessor(X_train).astype(np.float32)
print(trainset_input.shape)
trainset_outputs = {"output_1": trainset_input[:, :len(numerical_ids)]}
for i, cat_id in enumerate(categorical_ids):
    trainset_outputs.update({f"output_{i+2}": X_train[:, cat_id]})
trainset = tf.data.Dataset.from_tensor_slices((trainset_input, trainset_outputs))
trainset = trainset.shuffle(1024).batch(128, drop_remainder=True)
# Out:
# (26048, 57)

# %%
EPOCHS = 50 # epochs to train the autoencoder
HIDDEN_DIM = 128 # hidden dimension of the autoencoder
LATENT_DIM = 15 # define latent dimension
# Define output dimensions.
OUTPUT_DIMS = [len(numerical_ids)]
OUTPUT_DIMS += [len(adult.category_map[cat_id]) for cat_id in categorical_ids]
print(OUTPUT_DIMS)
# Out:
# [4, 9, 7, 4, 9, 6, 5, 2, 11]

# %%
# Define the heterogeneous auto-encoder.
heae = HeAE(encoder=ADULTEncoder(hidden_dim=HIDDEN_DIM, latent_dim=LATENT_DIM),
decoder=ADULTDecoder(hidden_dim=HIDDEN_DIM, output_dims=OUTPUT_DIMS))
# Define loss functions.
he_loss = [keras.losses.MeanSquaredError()]
he_loss_weights = [1.]
# Add categorical losses.
for i in range(len(categorical_names)):
    he_loss.append(keras.losses.SparseCategoricalCrossentropy(from_logits=True))
    he_loss_weights.append(1./len(categorical_names))
# Define metrics.
metrics = {}
for i, cat_name in enumerate(categorical_names):
    metrics.update({f"output_{i+2}": keras.metrics.SparseCategoricalAccuracy()})
# Compile model.
heae.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
loss=he_loss,
loss_weights=he_loss_weights,
metrics=metrics)

heae.fit(trainset, epochs=EPOCHS)
# Out:
# Epoch 1/50
# 203/203 [==============================] - 2s 2ms/step - loss: 1.1283 - output_1_loss: 0.2318 - output_2_loss: 1.1656 - output_3_loss: 1.1700 - output_4_loss: 0.6408 - output_5_loss: 1.5729 - output_6_loss: 0.9884 - output_7_loss: 0.5936 - output_8_loss: 0.3531 - output_9_loss: 0.6877 - output_2_sparse_categorical_accuracy: 0.6575 - output_3_sparse_categorical_accuracy: 0.6075 - output_4_sparse_categorical_accuracy: 0.7771 - output_5_sparse_categorical_accuracy: 0.4487 - output_6_sparse_categorical_accuracy: 0.6685 - output_7_sparse_categorical_accuracy: 0.8188 - output_8_sparse_categorical_accuracy: 0.8388 - output_9_sparse_categorical_accuracy: 0.8805
# Epoch 2/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.3951 - output_1_loss: 0.0422 - output_2_loss: 0.5100 - output_3_loss: 0.4868 - output_4_loss: 0.1598 - output_5_loss: 0.6723 - output_6_loss: 0.3369 - output_7_loss: 0.2322 - output_8_loss: 0.0936 - output_9_loss: 0.3317 - output_2_sparse_categorical_accuracy: 0.8339 - output_3_sparse_categorical_accuracy: 0.8463 - output_4_sparse_categorical_accuracy: 0.9640 - output_5_sparse_categorical_accuracy: 0.8031 - output_6_sparse_categorical_accuracy: 0.9102 - output_7_sparse_categorical_accuracy: 0.9244 - output_8_sparse_categorical_accuracy: 0.9789 - output_9_sparse_categorical_accuracy: 0.9110
# Epoch 3/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.2276 - output_1_loss: 0.0297 - output_2_loss: 0.2806 - output_3_loss: 0.2608 - output_4_loss: 0.1024 - output_5_loss: 0.3053 - output_6_loss: 0.1838 - output_7_loss: 0.1503 - output_8_loss: 0.0413 - output_9_loss: 0.2589 - output_2_sparse_categorical_accuracy: 0.9104 - output_3_sparse_categorical_accuracy: 0.9295 - output_4_sparse_categorical_accuracy: 0.9749 - output_5_sparse_categorical_accuracy: 0.9310 - output_6_sparse_categorical_accuracy: 0.9517 - output_7_sparse_categorical_accuracy: 0.9545 - output_8_sparse_categorical_accuracy: 0.9916 - output_9_sparse_categorical_accuracy: 0.9266
# Epoch 4/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.1670 - output_1_loss: 0.0223 - output_2_loss: 0.1999 - output_3_loss: 0.1769 - output_4_loss: 0.0791 - output_5_loss: 0.1995 - output_6_loss: 0.1388 - output_7_loss: 0.1236 - output_8_loss: 0.0261 - output_9_loss: 0.2140 - output_2_sparse_categorical_accuracy: 0.9417 - output_3_sparse_categorical_accuracy: 0.9545 - output_4_sparse_categorical_accuracy: 0.9784 - output_5_sparse_categorical_accuracy: 0.9530 - output_6_sparse_categorical_accuracy: 0.9637 - output_7_sparse_categorical_accuracy: 0.9607 - output_8_sparse_categorical_accuracy: 0.9950 - output_9_sparse_categorical_accuracy: 0.9369
# Epoch 5/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.1337 - output_1_loss: 0.0177 - output_2_loss: 0.1529 - output_3_loss: 0.1374 - output_4_loss: 0.0659 - output_5_loss: 0.1505 - output_6_loss: 0.1123 - output_7_loss: 0.1048 - output_8_loss: 0.0203 - output_9_loss: 0.1837 - output_2_sparse_categorical_accuracy: 0.9588 - output_3_sparse_categorical_accuracy: 0.9644 - output_4_sparse_categorical_accuracy: 0.9815 - output_5_sparse_categorical_accuracy: 0.9659 - output_6_sparse_categorical_accuracy: 0.9715 - output_7_sparse_categorical_accuracy: 0.9664 - output_8_sparse_categorical_accuracy: 0.9962 - output_9_sparse_categorical_accuracy: 0.9443
# Epoch 6/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.1104 - output_1_loss: 0.0150 - output_2_loss: 0.1210 - output_3_loss: 0.1094 - output_4_loss: 0.0555 - output_5_loss: 0.1163 - output_6_loss: 0.0925 - output_7_loss: 0.0905 - output_8_loss: 0.0164 - output_9_loss: 0.1612 - output_2_sparse_categorical_accuracy: 0.9688 - output_3_sparse_categorical_accuracy: 0.9719 - output_4_sparse_categorical_accuracy: 0.9849 - output_5_sparse_categorical_accuracy: 0.9755 - output_6_sparse_categorical_accuracy: 0.9761 - output_7_sparse_categorical_accuracy: 0.9708 - output_8_sparse_categorical_accuracy: 0.9970 - output_9_sparse_categorical_accuracy: 0.9502
# Epoch 7/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0934 - output_1_loss: 0.0132 - output_2_loss: 0.0997 - output_3_loss: 0.0893 - output_4_loss: 0.0472 - output_5_loss: 0.0929 - output_6_loss: 0.0775 - output_7_loss: 0.0787 - output_8_loss: 0.0133 - output_9_loss: 0.1434 - output_2_sparse_categorical_accuracy: 0.9737 - output_3_sparse_categorical_accuracy: 0.9782 - output_4_sparse_categorical_accuracy: 0.9875 - output_5_sparse_categorical_accuracy: 0.9810 - output_6_sparse_categorical_accuracy: 0.9800 - output_7_sparse_categorical_accuracy: 0.9748 - output_8_sparse_categorical_accuracy: 0.9976 - output_9_sparse_categorical_accuracy: 0.9559
# Epoch 8/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0817 - output_1_loss: 0.0122 - output_2_loss: 0.0848 - output_3_loss: 0.0766 - output_4_loss: 0.0408 - output_5_loss: 0.0764 - output_6_loss: 0.0657 - output_7_loss: 0.0701 - output_8_loss: 0.0115 - output_9_loss: 0.1305 - output_2_sparse_categorical_accuracy: 0.9778 - output_3_sparse_categorical_accuracy: 0.9807 - output_4_sparse_categorical_accuracy: 0.9896 - output_5_sparse_categorical_accuracy: 0.9838 - output_6_sparse_categorical_accuracy: 0.9835 - output_7_sparse_categorical_accuracy: 0.9781 - output_8_sparse_categorical_accuracy: 0.9979 - output_9_sparse_categorical_accuracy: 0.9598
# Epoch 9/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0723 - output_1_loss: 0.0110 - output_2_loss: 0.0739 - output_3_loss: 0.0670 - output_4_loss: 0.0362 - output_5_loss: 0.0650 - output_6_loss: 0.0568 - output_7_loss: 0.0628 - output_8_loss: 0.0098 - output_9_loss: 0.1188 - output_2_sparse_categorical_accuracy: 0.9801 - output_3_sparse_categorical_accuracy: 0.9836 - output_4_sparse_categorical_accuracy: 0.9910 - output_5_sparse_categorical_accuracy: 0.9860 - output_6_sparse_categorical_accuracy: 0.9862 - output_7_sparse_categorical_accuracy: 0.9808 - output_8_sparse_categorical_accuracy: 0.9985 - output_9_sparse_categorical_accuracy: 0.9649
# Epoch 10/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0649 - output_1_loss: 0.0101 - output_2_loss: 0.0650 - output_3_loss: 0.0598 - output_4_loss: 0.0325 - output_5_loss: 0.0568 - output_6_loss: 0.0501 - output_7_loss: 0.0567 - output_8_loss: 0.0088 - output_9_loss: 0.1087 - output_2_sparse_categorical_accuracy: 0.9827 - output_3_sparse_categorical_accuracy: 0.9848 - output_4_sparse_categorical_accuracy: 0.9916 - output_5_sparse_categorical_accuracy: 0.9873 - output_6_sparse_categorical_accuracy: 0.9875 - output_7_sparse_categorical_accuracy: 0.9833 - output_8_sparse_categorical_accuracy: 0.9986 - output_9_sparse_categorical_accuracy: 0.9688
# Epoch 11/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0587 - output_1_loss: 0.0094 - output_2_loss: 0.0583 - output_3_loss: 0.0533 - output_4_loss: 0.0296 - output_5_loss: 0.0496 - output_6_loss: 0.0444 - output_7_loss: 0.0515 - output_8_loss: 0.0080 - output_9_loss: 0.0997 - output_2_sparse_categorical_accuracy: 0.9846 - output_3_sparse_categorical_accuracy: 0.9862 - output_4_sparse_categorical_accuracy: 0.9926 - output_5_sparse_categorical_accuracy: 0.9890 - output_6_sparse_categorical_accuracy: 0.9891 - output_7_sparse_categorical_accuracy: 0.9848 - output_8_sparse_categorical_accuracy: 0.9986 - output_9_sparse_categorical_accuracy: 0.9716
# Epoch 12/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0536 - output_1_loss: 0.0088 - output_2_loss: 0.0523 - output_3_loss: 0.0483 - output_4_loss: 0.0268 - output_5_loss: 0.0448 - output_6_loss: 0.0394 - output_7_loss: 0.0470 - output_8_loss: 0.0073 - output_9_loss: 0.0920 - output_2_sparse_categorical_accuracy: 0.9860 - output_3_sparse_categorical_accuracy: 0.9879 - output_4_sparse_categorical_accuracy: 0.9935 - output_5_sparse_categorical_accuracy: 0.9906 - output_6_sparse_categorical_accuracy: 0.9909 - output_7_sparse_categorical_accuracy: 0.9863 - output_8_sparse_categorical_accuracy: 0.9987 - output_9_sparse_categorical_accuracy: 0.9739
# Epoch 13/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0490 - output_1_loss: 0.0084 - output_2_loss: 0.0473 - output_3_loss: 0.0442 - output_4_loss: 0.0250 - output_5_loss: 0.0404 - output_6_loss: 0.0346 - output_7_loss: 0.0422 - output_8_loss: 0.0066 - output_9_loss: 0.0850 - output_2_sparse_categorical_accuracy: 0.9875 - output_3_sparse_categorical_accuracy: 0.9881 - output_4_sparse_categorical_accuracy: 0.9937 - output_5_sparse_categorical_accuracy: 0.9913 - output_6_sparse_categorical_accuracy: 0.9920 - output_7_sparse_categorical_accuracy: 0.9883 - output_8_sparse_categorical_accuracy: 0.9987 - output_9_sparse_categorical_accuracy: 0.9763
# Epoch 14/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0451 - output_1_loss: 0.0079 - output_2_loss: 0.0425 - output_3_loss: 0.0405 - output_4_loss: 0.0234 - output_5_loss: 0.0364 - output_6_loss: 0.0313 - output_7_loss: 0.0387 - output_8_loss: 0.0061 - output_9_loss: 0.0787 - output_2_sparse_categorical_accuracy: 0.9890 - output_3_sparse_categorical_accuracy: 0.9891 - output_4_sparse_categorical_accuracy: 0.9944 - output_5_sparse_categorical_accuracy: 0.9924 - output_6_sparse_categorical_accuracy: 0.9929 - output_7_sparse_categorical_accuracy: 0.9891 - output_8_sparse_categorical_accuracy: 0.9990 - output_9_sparse_categorical_accuracy: 0.9791
# Epoch 15/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0416 - output_1_loss: 0.0076 - output_2_loss: 0.0387 - output_3_loss: 0.0368 - output_4_loss: 0.0217 - output_5_loss: 0.0336 - output_6_loss: 0.0283 - output_7_loss: 0.0348 - output_8_loss: 0.0054 - output_9_loss: 0.0728 - output_2_sparse_categorical_accuracy: 0.9899 - output_3_sparse_categorical_accuracy: 0.9906 - output_4_sparse_categorical_accuracy: 0.9946 - output_5_sparse_categorical_accuracy: 0.9931 - output_6_sparse_categorical_accuracy: 0.9941 - output_7_sparse_categorical_accuracy: 0.9907 - output_8_sparse_categorical_accuracy: 0.9990 - output_9_sparse_categorical_accuracy: 0.9805
# Epoch 16/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0382 - output_1_loss: 0.0071 - output_2_loss: 0.0354 - output_3_loss: 0.0338 - output_4_loss: 0.0202 - output_5_loss: 0.0305 - output_6_loss: 0.0253 - output_7_loss: 0.0313 - output_8_loss: 0.0052 - output_9_loss: 0.0669 - output_2_sparse_categorical_accuracy: 0.9912 - output_3_sparse_categorical_accuracy: 0.9909 - output_4_sparse_categorical_accuracy: 0.9951 - output_5_sparse_categorical_accuracy: 0.9939 - output_6_sparse_categorical_accuracy: 0.9944 - output_7_sparse_categorical_accuracy: 0.9916 - output_8_sparse_categorical_accuracy: 0.9991 - output_9_sparse_categorical_accuracy: 0.9818
# Epoch 17/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0354 - output_1_loss: 0.0068 - output_2_loss: 0.0328 - output_3_loss: 0.0310 - output_4_loss: 0.0189 - output_5_loss: 0.0280 - output_6_loss: 0.0233 - output_7_loss: 0.0282 - output_8_loss: 0.0047 - output_9_loss: 0.0620 - output_2_sparse_categorical_accuracy: 0.9923 - output_3_sparse_categorical_accuracy: 0.9918 - output_4_sparse_categorical_accuracy: 0.9955 - output_5_sparse_categorical_accuracy: 0.9938 - output_6_sparse_categorical_accuracy: 0.9951 - output_7_sparse_categorical_accuracy: 0.9926 - output_8_sparse_categorical_accuracy: 0.9991 - output_9_sparse_categorical_accuracy: 0.9836
# Epoch 18/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0330 - output_1_loss: 0.0066 - output_2_loss: 0.0298 - output_3_loss: 0.0288 - output_4_loss: 0.0178 - output_5_loss: 0.0259 - output_6_loss: 0.0216 - output_7_loss: 0.0257 - output_8_loss: 0.0046 - output_9_loss: 0.0571 - output_2_sparse_categorical_accuracy: 0.9928 - output_3_sparse_categorical_accuracy: 0.9925 - output_4_sparse_categorical_accuracy: 0.9959 - output_5_sparse_categorical_accuracy: 0.9947 - output_6_sparse_categorical_accuracy: 0.9950 - output_7_sparse_categorical_accuracy: 0.9931 - output_8_sparse_categorical_accuracy: 0.9990 - output_9_sparse_categorical_accuracy: 0.9851
# Epoch 19/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0306 - output_1_loss: 0.0062 - output_2_loss: 0.0279 - output_3_loss: 0.0265 - output_4_loss: 0.0167 - output_5_loss: 0.0238 - output_6_loss: 0.0196 - output_7_loss: 0.0233 - output_8_loss: 0.0041 - output_9_loss: 0.0530 - output_2_sparse_categorical_accuracy: 0.9933 - output_3_sparse_categorical_accuracy: 0.9930 - output_4_sparse_categorical_accuracy: 0.9960 - output_5_sparse_categorical_accuracy: 0.9948 - output_6_sparse_categorical_accuracy: 0.9958 - output_7_sparse_categorical_accuracy: 0.9941 - output_8_sparse_categorical_accuracy: 0.9993 - output_9_sparse_categorical_accuracy: 0.9862
# Epoch 20/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0286 - output_1_loss: 0.0061 - output_2_loss: 0.0258 - output_3_loss: 0.0246 - output_4_loss: 0.0155 - output_5_loss: 0.0219 - output_6_loss: 0.0182 - output_7_loss: 0.0217 - output_8_loss: 0.0039 - output_9_loss: 0.0488 - output_2_sparse_categorical_accuracy: 0.9940 - output_3_sparse_categorical_accuracy: 0.9935 - output_4_sparse_categorical_accuracy: 0.9964 - output_5_sparse_categorical_accuracy: 0.9955 - output_6_sparse_categorical_accuracy: 0.9961 - output_7_sparse_categorical_accuracy: 0.9945 - output_8_sparse_categorical_accuracy: 0.9992 - output_9_sparse_categorical_accuracy: 0.9873
# Epoch 21/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0269 - output_1_loss: 0.0059 - output_2_loss: 0.0243 - output_3_loss: 0.0229 - output_4_loss: 0.0148 - output_5_loss: 0.0203 - output_6_loss: 0.0166 - output_7_loss: 0.0197 - output_8_loss: 0.0037 - output_9_loss: 0.0457 - output_2_sparse_categorical_accuracy: 0.9947 - output_3_sparse_categorical_accuracy: 0.9939 - output_4_sparse_categorical_accuracy: 0.9963 - output_5_sparse_categorical_accuracy: 0.9961 - output_6_sparse_categorical_accuracy: 0.9966 - output_7_sparse_categorical_accuracy: 0.9949 - output_8_sparse_categorical_accuracy: 0.9993 - output_9_sparse_categorical_accuracy: 0.9882
# Epoch 22/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0252 - output_1_loss: 0.0056 - output_2_loss: 0.0227 - output_3_loss: 0.0212 - output_4_loss: 0.0141 - output_5_loss: 0.0187 - output_6_loss: 0.0158 - output_7_loss: 0.0186 - output_8_loss: 0.0033 - output_9_loss: 0.0424 - output_2_sparse_categorical_accuracy: 0.9950 - output_3_sparse_categorical_accuracy: 0.9945 - output_4_sparse_categorical_accuracy: 0.9968 - output_5_sparse_categorical_accuracy: 0.9960 - output_6_sparse_categorical_accuracy: 0.9969 - output_7_sparse_categorical_accuracy: 0.9953 - output_8_sparse_categorical_accuracy: 0.9994 - output_9_sparse_categorical_accuracy: 0.9888
# Epoch 23/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0238 - output_1_loss: 0.0055 - output_2_loss: 0.0211 - output_3_loss: 0.0197 - output_4_loss: 0.0134 - output_5_loss: 0.0174 - output_6_loss: 0.0148 - output_7_loss: 0.0174 - output_8_loss: 0.0033 - output_9_loss: 0.0395 - output_2_sparse_categorical_accuracy: 0.9953 - output_3_sparse_categorical_accuracy: 0.9954 - output_4_sparse_categorical_accuracy: 0.9969 - output_5_sparse_categorical_accuracy: 0.9965 - output_6_sparse_categorical_accuracy: 0.9968 - output_7_sparse_categorical_accuracy: 0.9956 - output_8_sparse_categorical_accuracy: 0.9995 - output_9_sparse_categorical_accuracy: 0.9899
# Epoch 24/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0223 - output_1_loss: 0.0051 - output_2_loss: 0.0199 - output_3_loss: 0.0185 - output_4_loss: 0.0127 - output_5_loss: 0.0164 - output_6_loss: 0.0136 - output_7_loss: 0.0165 - output_8_loss: 0.0029 - output_9_loss: 0.0367 - output_2_sparse_categorical_accuracy: 0.9956 - output_3_sparse_categorical_accuracy: 0.9953 - output_4_sparse_categorical_accuracy: 0.9968 - output_5_sparse_categorical_accuracy: 0.9966 - output_6_sparse_categorical_accuracy: 0.9969 - output_7_sparse_categorical_accuracy: 0.9959 - output_8_sparse_categorical_accuracy: 0.9995 - output_9_sparse_categorical_accuracy: 0.9905
# Epoch 25/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0209 - output_1_loss: 0.0049 - output_2_loss: 0.0187 - output_3_loss: 0.0170 - output_4_loss: 0.0119 - output_5_loss: 0.0151 - output_6_loss: 0.0130 - output_7_loss: 0.0153 - output_8_loss: 0.0028 - output_9_loss: 0.0345 - output_2_sparse_categorical_accuracy: 0.9959 - output_3_sparse_categorical_accuracy: 0.9960 - output_4_sparse_categorical_accuracy: 0.9968 - output_5_sparse_categorical_accuracy: 0.9969 - output_6_sparse_categorical_accuracy: 0.9972 - output_7_sparse_categorical_accuracy: 0.9960 - output_8_sparse_categorical_accuracy: 0.9996 - output_9_sparse_categorical_accuracy: 0.9914
# Epoch 26/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0200 - output_1_loss: 0.0048 - output_2_loss: 0.0175 - output_3_loss: 0.0161 - output_4_loss: 0.0117 - output_5_loss: 0.0141 - output_6_loss: 0.0120 - output_7_loss: 0.0146 - output_8_loss: 0.0030 - output_9_loss: 0.0322 - output_2_sparse_categorical_accuracy: 0.9962 - output_3_sparse_categorical_accuracy: 0.9962 - output_4_sparse_categorical_accuracy: 0.9974 - output_5_sparse_categorical_accuracy: 0.9974 - output_6_sparse_categorical_accuracy: 0.9973 - output_7_sparse_categorical_accuracy: 0.9966 - output_8_sparse_categorical_accuracy: 0.9994 - output_9_sparse_categorical_accuracy: 0.9919
# Epoch 27/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0192 - output_1_loss: 0.0047 - output_2_loss: 0.0168 - output_3_loss: 0.0153 - output_4_loss: 0.0110 - output_5_loss: 0.0137 - output_6_loss: 0.0116 - output_7_loss: 0.0139 - output_8_loss: 0.0027 - output_9_loss: 0.0311 - output_2_sparse_categorical_accuracy: 0.9962 - output_3_sparse_categorical_accuracy: 0.9961 - output_4_sparse_categorical_accuracy: 0.9976 - output_5_sparse_categorical_accuracy: 0.9973 - output_6_sparse_categorical_accuracy: 0.9976 - output_7_sparse_categorical_accuracy: 0.9968 - output_8_sparse_categorical_accuracy: 0.9995 - output_9_sparse_categorical_accuracy: 0.9923
# Epoch 28/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0183 - output_1_loss: 0.0046 - output_2_loss: 0.0157 - output_3_loss: 0.0144 - output_4_loss: 0.0106 - output_5_loss: 0.0129 - output_6_loss: 0.0112 - output_7_loss: 0.0131 - output_8_loss: 0.0026 - output_9_loss: 0.0289 - output_2_sparse_categorical_accuracy: 0.9967 - output_3_sparse_categorical_accuracy: 0.9967 - output_4_sparse_categorical_accuracy: 0.9976 - output_5_sparse_categorical_accuracy: 0.9975 - output_6_sparse_categorical_accuracy: 0.9978 - output_7_sparse_categorical_accuracy: 0.9968 - output_8_sparse_categorical_accuracy: 0.9995 - output_9_sparse_categorical_accuracy: 0.9934
# Epoch 29/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0170 - output_1_loss: 0.0043 - output_2_loss: 0.0149 - output_3_loss: 0.0134 - output_4_loss: 0.0101 - output_5_loss: 0.0118 - output_6_loss: 0.0099 - output_7_loss: 0.0121 - output_8_loss: 0.0022 - output_9_loss: 0.0271 - output_2_sparse_categorical_accuracy: 0.9969 - output_3_sparse_categorical_accuracy: 0.9969 - output_4_sparse_categorical_accuracy: 0.9979 - output_5_sparse_categorical_accuracy: 0.9978 - output_6_sparse_categorical_accuracy: 0.9979 - output_7_sparse_categorical_accuracy: 0.9970 - output_8_sparse_categorical_accuracy: 0.9997 - output_9_sparse_categorical_accuracy: 0.9936
# Epoch 30/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0165 - output_1_loss: 0.0043 - output_2_loss: 0.0137 - output_3_loss: 0.0130 - output_4_loss: 0.0099 - output_5_loss: 0.0116 - output_6_loss: 0.0098 - output_7_loss: 0.0118 - output_8_loss: 0.0022 - output_9_loss: 0.0260 - output_2_sparse_categorical_accuracy: 0.9972 - output_3_sparse_categorical_accuracy: 0.9968 - output_4_sparse_categorical_accuracy: 0.9979 - output_5_sparse_categorical_accuracy: 0.9979 - output_6_sparse_categorical_accuracy: 0.9982 - output_7_sparse_categorical_accuracy: 0.9973 - output_8_sparse_categorical_accuracy: 0.9997 - output_9_sparse_categorical_accuracy: 0.9936
# Epoch 31/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0158 - output_1_loss: 0.0043 - output_2_loss: 0.0132 - output_3_loss: 0.0118 - output_4_loss: 0.0094 - output_5_loss: 0.0108 - output_6_loss: 0.0090 - output_7_loss: 0.0109 - output_8_loss: 0.0022 - output_9_loss: 0.0246 - output_2_sparse_categorical_accuracy: 0.9974 - output_3_sparse_categorical_accuracy: 0.9975 - output_4_sparse_categorical_accuracy: 0.9980 - output_5_sparse_categorical_accuracy: 0.9979 - output_6_sparse_categorical_accuracy: 0.9983 - output_7_sparse_categorical_accuracy: 0.9976 - output_8_sparse_categorical_accuracy: 0.9996 - output_9_sparse_categorical_accuracy: 0.9943
# Epoch 32/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0152 - output_1_loss: 0.0043 - output_2_loss: 0.0125 - output_3_loss: 0.0111 - output_4_loss: 0.0088 - output_5_loss: 0.0098 - output_6_loss: 0.0088 - output_7_loss: 0.0105 - output_8_loss: 0.0020 - output_9_loss: 0.0234 - output_2_sparse_categorical_accuracy: 0.9974 - output_3_sparse_categorical_accuracy: 0.9977 - output_4_sparse_categorical_accuracy: 0.9983 - output_5_sparse_categorical_accuracy: 0.9985 - output_6_sparse_categorical_accuracy: 0.9985 - output_7_sparse_categorical_accuracy: 0.9973 - output_8_sparse_categorical_accuracy: 0.9997 - output_9_sparse_categorical_accuracy: 0.9943
# Epoch 33/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0144 - output_1_loss: 0.0040 - output_2_loss: 0.0119 - output_3_loss: 0.0108 - output_4_loss: 0.0085 - output_5_loss: 0.0096 - output_6_loss: 0.0085 - output_7_loss: 0.0099 - output_8_loss: 0.0020 - output_9_loss: 0.0217 - output_2_sparse_categorical_accuracy: 0.9976 - output_3_sparse_categorical_accuracy: 0.9977 - output_4_sparse_categorical_accuracy: 0.9982 - output_5_sparse_categorical_accuracy: 0.9982 - output_6_sparse_categorical_accuracy: 0.9986 - output_7_sparse_categorical_accuracy: 0.9977 - output_8_sparse_categorical_accuracy: 0.9996 - output_9_sparse_categorical_accuracy: 0.9949
# Epoch 34/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0135 - output_1_loss: 0.0038 - output_2_loss: 0.0109 - output_3_loss: 0.0099 - output_4_loss: 0.0082 - output_5_loss: 0.0089 - output_6_loss: 0.0077 - output_7_loss: 0.0096 - output_8_loss: 0.0018 - output_9_loss: 0.0210 - output_2_sparse_categorical_accuracy: 0.9978 - output_3_sparse_categorical_accuracy: 0.9980 - output_4_sparse_categorical_accuracy: 0.9984 - output_5_sparse_categorical_accuracy: 0.9983 - output_6_sparse_categorical_accuracy: 0.9987 - output_7_sparse_categorical_accuracy: 0.9979 - output_8_sparse_categorical_accuracy: 0.9997 - output_9_sparse_categorical_accuracy: 0.9950
# Epoch 35/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0131 - output_1_loss: 0.0038 - output_2_loss: 0.0102 - output_3_loss: 0.0096 - output_4_loss: 0.0080 - output_5_loss: 0.0087 - output_6_loss: 0.0072 - output_7_loss: 0.0090 - output_8_loss: 0.0017 - output_9_loss: 0.0200 - output_2_sparse_categorical_accuracy: 0.9980 - output_3_sparse_categorical_accuracy: 0.9982 - output_4_sparse_categorical_accuracy: 0.9985 - output_5_sparse_categorical_accuracy: 0.9986 - output_6_sparse_categorical_accuracy: 0.9989 - output_7_sparse_categorical_accuracy: 0.9980 - output_8_sparse_categorical_accuracy: 0.9998 - output_9_sparse_categorical_accuracy: 0.9950
# Epoch 36/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0124 - output_1_loss: 0.0036 - output_2_loss: 0.0098 - output_3_loss: 0.0090 - output_4_loss: 0.0075 - output_5_loss: 0.0080 - output_6_loss: 0.0071 - output_7_loss: 0.0086 - output_8_loss: 0.0017 - output_9_loss: 0.0186 - output_2_sparse_categorical_accuracy: 0.9980 - output_3_sparse_categorical_accuracy: 0.9982 - output_4_sparse_categorical_accuracy: 0.9981 - output_5_sparse_categorical_accuracy: 0.9989 - output_6_sparse_categorical_accuracy: 0.9987 - output_7_sparse_categorical_accuracy: 0.9980 - output_8_sparse_categorical_accuracy: 0.9997 - output_9_sparse_categorical_accuracy: 0.9954
# Epoch 37/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0119 - output_1_loss: 0.0036 - output_2_loss: 0.0091 - output_3_loss: 0.0083 - output_4_loss: 0.0073 - output_5_loss: 0.0075 - output_6_loss: 0.0066 - output_7_loss: 0.0084 - output_8_loss: 0.0016 - output_9_loss: 0.0176 - output_2_sparse_categorical_accuracy: 0.9982 - output_3_sparse_categorical_accuracy: 0.9984 - output_4_sparse_categorical_accuracy: 0.9985 - output_5_sparse_categorical_accuracy: 0.9991 - output_6_sparse_categorical_accuracy: 0.9989 - output_7_sparse_categorical_accuracy: 0.9983 - output_8_sparse_categorical_accuracy: 0.9997 - output_9_sparse_categorical_accuracy: 0.9959
# Epoch 38/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0114 - output_1_loss: 0.0035 - output_2_loss: 0.0085 - output_3_loss: 0.0080 - output_4_loss: 0.0070 - output_5_loss: 0.0072 - output_6_loss: 0.0066 - output_7_loss: 0.0079 - output_8_loss: 0.0017 - output_9_loss: 0.0167 - output_2_sparse_categorical_accuracy: 0.9984 - output_3_sparse_categorical_accuracy: 0.9988 - output_4_sparse_categorical_accuracy: 0.9987 - output_5_sparse_categorical_accuracy: 0.9992 - output_6_sparse_categorical_accuracy: 0.9987 - output_7_sparse_categorical_accuracy: 0.9983 - output_8_sparse_categorical_accuracy: 0.9999 - output_9_sparse_categorical_accuracy: 0.9957
# Epoch 39/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0111 - output_1_loss: 0.0034 - output_2_loss: 0.0084 - output_3_loss: 0.0079 - output_4_loss: 0.0066 - output_5_loss: 0.0069 - output_6_loss: 0.0062 - output_7_loss: 0.0076 - output_8_loss: 0.0015 - output_9_loss: 0.0159 - output_2_sparse_categorical_accuracy: 0.9983 - output_3_sparse_categorical_accuracy: 0.9986 - output_4_sparse_categorical_accuracy: 0.9986 - output_5_sparse_categorical_accuracy: 0.9990 - output_6_sparse_categorical_accuracy: 0.9990 - output_7_sparse_categorical_accuracy: 0.9983 - output_8_sparse_categorical_accuracy: 0.9998 - output_9_sparse_categorical_accuracy: 0.9960
# Epoch 40/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0106 - output_1_loss: 0.0034 - output_2_loss: 0.0076 - output_3_loss: 0.0073 - output_4_loss: 0.0064 - output_5_loss: 0.0067 - output_6_loss: 0.0059 - output_7_loss: 0.0074 - output_8_loss: 0.0014 - output_9_loss: 0.0151 - output_2_sparse_categorical_accuracy: 0.9985 - output_3_sparse_categorical_accuracy: 0.9989 - output_4_sparse_categorical_accuracy: 0.9987 - output_5_sparse_categorical_accuracy: 0.9990 - output_6_sparse_categorical_accuracy: 0.9987 - output_7_sparse_categorical_accuracy: 0.9983 - output_8_sparse_categorical_accuracy: 0.9998 - output_9_sparse_categorical_accuracy: 0.9962
# Epoch 41/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0102 - output_1_loss: 0.0033 - output_2_loss: 0.0074 - output_3_loss: 0.0068 - output_4_loss: 0.0061 - output_5_loss: 0.0063 - output_6_loss: 0.0056 - output_7_loss: 0.0070 - output_8_loss: 0.0014 - output_9_loss: 0.0144 - output_2_sparse_categorical_accuracy: 0.9985 - output_3_sparse_categorical_accuracy: 0.9987 - output_4_sparse_categorical_accuracy: 0.9989 - output_5_sparse_categorical_accuracy: 0.9990 - output_6_sparse_categorical_accuracy: 0.9992 - output_7_sparse_categorical_accuracy: 0.9985 - output_8_sparse_categorical_accuracy: 0.9999 - output_9_sparse_categorical_accuracy: 0.9964
# Epoch 42/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0100 - output_1_loss: 0.0032 - output_2_loss: 0.0071 - output_3_loss: 0.0067 - output_4_loss: 0.0064 - output_5_loss: 0.0061 - output_6_loss: 0.0056 - output_7_loss: 0.0067 - output_8_loss: 0.0013 - output_9_loss: 0.0139 - output_2_sparse_categorical_accuracy: 0.9988 - output_3_sparse_categorical_accuracy: 0.9988 - output_4_sparse_categorical_accuracy: 0.9987 - output_5_sparse_categorical_accuracy: 0.9990 - output_6_sparse_categorical_accuracy: 0.9991 - output_7_sparse_categorical_accuracy: 0.9985 - output_8_sparse_categorical_accuracy: 0.9999 - output_9_sparse_categorical_accuracy: 0.9965
# Epoch 43/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0096 - output_1_loss: 0.0031 - output_2_loss: 0.0074 - output_3_loss: 0.0061 - output_4_loss: 0.0061 - output_5_loss: 0.0057 - output_6_loss: 0.0054 - output_7_loss: 0.0064 - output_8_loss: 0.0014 - output_9_loss: 0.0129 - output_2_sparse_categorical_accuracy: 0.9986 - output_3_sparse_categorical_accuracy: 0.9991 - output_4_sparse_categorical_accuracy: 0.9986 - output_5_sparse_categorical_accuracy: 0.9991 - output_6_sparse_categorical_accuracy: 0.9992 - output_7_sparse_categorical_accuracy: 0.9988 - output_8_sparse_categorical_accuracy: 0.9997 - output_9_sparse_categorical_accuracy: 0.9969
# Epoch 44/50
# 203/203 [==============================] - 1s 2ms/step - loss: 0.0089 - output_1_loss: 0.0030 - output_2_loss: 0.0062 - output_3_loss: 0.0058 - output_4_loss: 0.0054 - output_5_loss: 0.0054 - output_6_loss: 0.0049 - output_7_loss: 0.0060 - output_8_loss: 0.0012 - output_9_loss: 0.0122 - output_2_sparse_categorical_accuracy: 0.9990 - output_3_sparse_categorical_accuracy: 0.9991 - output_4_sparse_categorical_accuracy: 0.9991 - output_5_sparse_categorical_accuracy: 0.9990 - output_6_sparse_categorical_accuracy: 0.9992 - output_7_sparse_categorical_accuracy: 0.9987 - output_8_sparse_categorical_accuracy: 0.9998 - output_9_sparse_categorical_accuracy: 0.9972
# Epoch 45/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0086 - output_1_loss: 0.0030 - output_2_loss: 0.0060 - output_3_loss: 0.0056 - output_4_loss: 0.0053 - output_5_loss: 0.0053 - output_6_loss: 0.0046 - output_7_loss: 0.0057 - output_8_loss: 0.0012 - output_9_loss: 0.0116 - output_2_sparse_categorical_accuracy: 0.9990 - output_3_sparse_categorical_accuracy: 0.9995 - output_4_sparse_categorical_accuracy: 0.9992 - output_5_sparse_categorical_accuracy: 0.9992 - output_6_sparse_categorical_accuracy: 0.9993 - output_7_sparse_categorical_accuracy: 0.9988 - output_8_sparse_categorical_accuracy: 0.9999 - output_9_sparse_categorical_accuracy: 0.9976
# Epoch 46/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0083 - output_1_loss: 0.0029 - output_2_loss: 0.0055 - output_3_loss: 0.0053 - output_4_loss: 0.0049 - output_5_loss: 0.0050 - output_6_loss: 0.0044 - output_7_loss: 0.0056 - output_8_loss: 0.0011 - output_9_loss: 0.0109 - output_2_sparse_categorical_accuracy: 0.9992 - output_3_sparse_categorical_accuracy: 0.9992 - output_4_sparse_categorical_accuracy: 0.9993 - output_5_sparse_categorical_accuracy: 0.9995 - output_6_sparse_categorical_accuracy: 0.9994 - output_7_sparse_categorical_accuracy: 0.9987 - output_8_sparse_categorical_accuracy: 1.0000 - output_9_sparse_categorical_accuracy: 0.9978
# Epoch 47/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0082 - output_1_loss: 0.0029 - output_2_loss: 0.0054 - output_3_loss: 0.0051 - output_4_loss: 0.0048 - output_5_loss: 0.0049 - output_6_loss: 0.0044 - output_7_loss: 0.0054 - output_8_loss: 0.0011 - output_9_loss: 0.0106 - output_2_sparse_categorical_accuracy: 0.9992 - output_3_sparse_categorical_accuracy: 0.9995 - output_4_sparse_categorical_accuracy: 0.9994 - output_5_sparse_categorical_accuracy: 0.9992 - output_6_sparse_categorical_accuracy: 0.9993 - output_7_sparse_categorical_accuracy: 0.9990 - output_8_sparse_categorical_accuracy: 0.9999 - output_9_sparse_categorical_accuracy: 0.9978
# Epoch 48/50
# 203/203 [==============================] - 1s 2ms/step - loss: 0.0080 - output_1_loss: 0.0029 - output_2_loss: 0.0057 - output_3_loss: 0.0048 - output_4_loss: 0.0049 - output_5_loss: 0.0046 - output_6_loss: 0.0046 - output_7_loss: 0.0050 - output_8_loss: 0.0012 - output_9_loss: 0.0101 - output_2_sparse_categorical_accuracy: 0.9989 - output_3_sparse_categorical_accuracy: 0.9993 - output_4_sparse_categorical_accuracy: 0.9990 - output_5_sparse_categorical_accuracy: 0.9994 - output_6_sparse_categorical_accuracy: 0.9991 - output_7_sparse_categorical_accuracy: 0.9992 - output_8_sparse_categorical_accuracy: 0.9998 - output_9_sparse_categorical_accuracy: 0.9981
# Epoch 49/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0076 - output_1_loss: 0.0029 - output_2_loss: 0.0048 - output_3_loss: 0.0045 - output_4_loss: 0.0044 - output_5_loss: 0.0044 - output_6_loss: 0.0041 - output_7_loss: 0.0051 - output_8_loss: 0.0010 - output_9_loss: 0.0096 - output_2_sparse_categorical_accuracy: 0.9994 - output_3_sparse_categorical_accuracy: 0.9995 - output_4_sparse_categorical_accuracy: 0.9993 - output_5_sparse_categorical_accuracy: 0.9994 - output_6_sparse_categorical_accuracy: 0.9994 - output_7_sparse_categorical_accuracy: 0.9989 - output_8_sparse_categorical_accuracy: 0.9998 - output_9_sparse_categorical_accuracy: 0.9982
# Epoch 50/50
# 203/203 [==============================] - 0s 2ms/step - loss: 0.0075 - output_1_loss: 0.0027 - output_2_loss: 0.0050 - output_3_loss: 0.0044 - output_4_loss: 0.0046 - output_5_loss: 0.0043 - output_6_loss: 0.0041 - output_7_loss: 0.0051 - output_8_loss: 0.0011 - output_9_loss: 0.0096 - output_2_sparse_categorical_accuracy: 0.9992 - output_3_sparse_categorical_accuracy: 0.9995 - output_4_sparse_categorical_accuracy: 0.9990 - output_5_sparse_categorical_accuracy: 0.9993 - output_6_sparse_categorical_accuracy: 0.9992 - output_7_sparse_categorical_accuracy: 0.9990 - output_8_sparse_categorical_accuracy: 0.9997 - output_9_sparse_categorical_accuracy: 0.9979

# %%
 # Define constants
COEFF_SPARSITY = 0.5 # sparisty coefficient
COEFF_CONSISTENCY = 0.5 # consisteny coefficient
TRAIN_STEPS = 10000 # number of training steps -> consider increasing the␣number of steps
BATCH_SIZE = 100 # batch size

# %% [markdown]
# Define dataset specific attributes and constraints
# A desirable property of a method for generating counterfactuals is to allow feature conditioning. Real-world datasets
# usually include immutable features such as Sex or Race, which should remain unchanged throughout the counterfactual
# search procedure. Similarly, a numerical feature such as Age should only increase for a counterfactual to be actionable.

# %%
# Define immutable features.
immutable_features = ['Marital Status', 'Relationship', 'Race', 'Sex']
# Define ranges. This means that the `Age` feature can not decrease.
ranges = {'Age': [0.0, 1.0]}

# %%
explainer = CounterfactualRLTabular(predictor=predictor,
encoder=heae.encoder,
decoder=heae.decoder,
latent_dim=LATENT_DIM,
encoder_preprocessor=heae_preprocessor,
decoder_inv_preprocessor=heae_inv_preprocessor,
coeff_sparsity=COEFF_SPARSITY,
coeff_consistency=COEFF_CONSISTENCY,
category_map=adult.category_map,
feature_names=adult.feature_names,
ranges=ranges,
immutable_features=immutable_features,
train_steps=TRAIN_STEPS,
batch_size=BATCH_SIZE,
backend="tensorflow")

# %%
# Fit the explainer.
explainer = explainer.fit(X=X_train)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [06:29<00:00, 25.71it/s]

# %%
# Select some positive examples.
X_positive = X_test[np.argmax(predictor(X_test), axis=1) == 1]
X = X_positive[:1000]
Y_t = np.array([0])
C = [{"Age": [0, 20], "Workclass": ["State-gov", "?", "Local-gov"]}]

# %%
# Generate counterfactual instances.
explanation = explainer.explain(X, Y_t, C)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.95it/s]

# %%
# Concat labels to the original instances.
orig = np.concatenate(
[explanation.data['orig']['X'], explanation.data['orig']['class']],axis=1)
# Concat labels to the counterfactual instances.
cf = np.concatenate(
[explanation.data['cf']['X'], explanation.data['cf']['class']],axis=1)
# Define new feature names and category map by including the label.
feature_names = adult.feature_names + ["Label"]
category_map = deepcopy(adult.category_map)
category_map.update({feature_names.index("Label"): adult.target_names})
# Replace label encodings with strings.
orig_pd = pd.DataFrame(
apply_category_mapping(orig, category_map),
columns=feature_names)
cf_pd = pd.DataFrame(
apply_category_mapping(cf, category_map),
columns=feature_names)

# %%
orig_pd.head(n=10)
# Out:
#   Age     Workclass         Education Marital Status    Occupation  \
# 0  60       Private  High School grad        Married   Blue-Collar
# 1  35       Private  High School grad        Married  White-Collar
# 2  39     State-gov           Masters        Married  Professional
# 3  44  Self-emp-inc  High School grad        Married         Sales
# 4  39       Private         Bachelors      Separated  White-Collar
# 5  45       Private  High School grad        Married   Blue-Collar
# 6  50       Private         Bachelors        Married  Professional
# 7  29       Private         Bachelors        Married  White-Collar
# 8  47       Private         Bachelors        Married  Professional
# 9  35       Private         Bachelors        Married  White-Collar
#
#     Relationship   Race     Sex Capital Gain Capital Loss Hours per week  \
# 0        Husband  White    Male         7298            0             40
# 1        Husband  White    Male         7688            0             50
# 2           Wife  White  Female         5178            0             38
# 3        Husband  White    Male            0            0             50
# 4  Not-in-family  White  Female        13550            0             50
# 5        Husband  White    Male            0         1902             40
# 6        Husband  White    Male            0            0             50
# 7           Wife  White  Female            0            0             50
# 8        Husband  White    Male            0            0             50
# 9        Husband  White    Male            0            0             70
#
#          Country Label
# 0  United-States  >50K
# 1  United-States  >50K
# 2  United-States  >50K
# 3  United-States  >50K
# 4  United-States  >50K
# 5              ?  >50K
# 6  United-States  >50K
# 7  United-States  >50K
# 8  United-States  >50K
# 9  United-States  >50K

# %%
cf_pd.head(n=10)
# Out:
#   Age     Workclass         Education Marital Status   Occupation  \
# 0  60       Private  High School grad        Married  Blue-Collar
# 1  35       Private  High School grad        Married  Blue-Collar
# 2  39     State-gov           Dropout        Married      Service
# 3  44  Self-emp-inc  High School grad        Married  Blue-Collar
# 4  39       Private         Bachelors      Separated        Admin
# 5  45       Private  High School grad        Married  Blue-Collar
# 6  50       Private           Dropout        Married  Blue-Collar
# 7  29       Private  High School grad        Married  Blue-Collar
# 8  47       Private           Dropout        Married  Blue-Collar
# 9  35       Private  High School grad        Married  Blue-Collar
#
#     Relationship   Race     Sex Capital Gain Capital Loss Hours per week  \
# 0        Husband  White    Male          161            0             40
# 1        Husband  White    Male          149            0             50
# 2           Wife  White  Female          488            0             37
# 3        Husband  White    Male           51            0             51
# 4  Not-in-family  White  Female          157            0             49
# 5        Husband  White    Male            0         1867             37
# 6        Husband  White    Male           90            2             49
# 7           Wife  White  Female          347            1             50
# 8        Husband  White    Male           68            3             49
# 9        Husband  White    Male          163            0             70
#
#          Country  Label
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States  <=50K
# 3  United-States  <=50K
# 4  United-States  <=50K
# 5  Latin-America   >50K
# 6  United-States  <=50K
# 7  United-States  <=50K
# 8  United-States  <=50K
# 9  United-States  <=50K

# %%
# Generate counterfactual instances.
X = X_positive[0].reshape(1, -1)
explanation = explainer.explain(X=X, Y_t=Y_t, C=C, diversity=True, num_samples=100,batch_size=10)
# Out:
# 13it [00:00, 42.66it/s]

# %%
# Concat label column.
orig = np.concatenate(
[explanation.data['orig']['X'], explanation.data['orig']['class']],axis=1)
cf = np.concatenate(
[explanation.data['cf']['X'], explanation.data['cf']['class']],axis=1)
# Transfrom label encodings to string.
orig_pd = pd.DataFrame(
apply_category_mapping(orig, category_map),
columns=feature_names,
)
cf_pd = pd.DataFrame(
apply_category_mapping(cf, category_map),
columns=feature_names,
)

# %%
orig_pd.head(n=5)
# Out:
#   Age Workclass         Education Marital Status   Occupation Relationship  \
# 0  60   Private  High School grad        Married  Blue-Collar      Husband
#
#     Race   Sex Capital Gain Capital Loss Hours per week        Country Label
# 0  White  Male         7298            0             40  United-States  >50K

# %%
 cf_pd.head(n=5)
# Out:
#   Age Workclass         Education Marital Status   Occupation Relationship  \
# 0  60   Private  High School grad        Married  Blue-Collar      Husband
# 1  60   Private  High School grad        Married  Blue-Collar      Husband
# 2  60   Private  High School grad        Married  Blue-Collar      Husband
# 3  60   Private  High School grad        Married  Blue-Collar      Husband
# 4  60   Private  High School grad        Married  Blue-Collar      Husband
#
#     Race   Sex Capital Gain Capital Loss Hours per week        Country  Label
# 0  White  Male          165            0             39  United-States  <=50K
# 1  White  Male          169            0             39  United-States  <=50K
# 2  White  Male          170            0             39  United-States  <=50K
# 3  White  Male          170            0             40  United-States  <=50K
# 4  White  Male          172            0             39  United-States  <=50K
