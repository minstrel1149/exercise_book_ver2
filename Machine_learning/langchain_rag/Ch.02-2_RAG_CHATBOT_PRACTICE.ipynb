# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_experimental.text_splitter import SemanticChunker
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

# %%
loader = PyPDFLoader('./data/2024_KB_부동산_보고서_최종.pdf')
documents = loader.load()
text_splitter = SemanticChunker(embeddings=OpenAIEmbeddings())
chunks = text_splitter.split_documents(documents)
print(len(chunks))
# Out:
# 164

# %%
persist_dir = './data/rag_practice_chroma'
vectordb = Chroma.from_documents(documents=chunks, embedding=OpenAIEmbeddings(), persist_directory=persist_dir)
print(vectordb._collection.count())
# Out:
# 164

# %%
retriever = vectordb.as_retriever(search_kwargs={'k':3})

# %%
def format_docs(docs):
    return '\n\n'.join(doc.page_content for doc in docs)

# %%
template = '''당신은 KB 부동산 보고서 전문가입니다. 다음 정보를 바탕으로 사용자의 질문에 답변해주세요.
컨텍스트: {context}'''

prompt = ChatPromptTemplate.from_messages(
    [('system', template),
     ('placeholder', '{chat_history}'),
     ('human', '{question}')]
)

model = ChatOpenAI(model='gpt-5-nano', temperature=0)

# %%
print(prompt.format(context='컨텍스트 예시', chat_history=['대화 기록 예시1', '대화 기록 예시2'], question='질문 예시'))
# Out:
# System: 당신은 KB 부동산 보고서 전문가입니다. 다음 정보를 바탕으로 사용자의 질문에 답변해주세요.
# 컨텍스트: 컨텍스트 예시
# Human: 대화 기록 예시1
# Human: 대화 기록 예시2
# Human: 질문 예시

# %%
chain = (
    RunnablePassthrough.assign(context=lambda x: format_docs(retriever.invoke(x['question'])))
    | prompt
    | model
    | StrOutputParser()
)

# %%
chat_history = ChatMessageHistory()

chain_with_memory = RunnableWithMessageHistory(
    chain,
    lambda session_id: chat_history,
    input_messages_key='question',
    history_messages_key='chat_history'
)

# %%
def chat_with_bot():
    session_id = 'user_session'
    print('KB 부동산 보고서 챗봇입니다. 질문해주세요. (종료하려면 "종료"를 입력해주세요.)')
    while True:
        user_input = input('사용자: ')
        if user_input == '종료' or user_input.lower() == 'quit':
            break

        response = chain_with_memory.invoke(
            {'question':user_input},
            {'configurable':{'session_id':session_id}}
        )

        print(f'챗봇: {response}')

# %%
chat_with_bot()
# Out:
# KB 부동산 보고서 챗봇입니다. 질문해주세요. (종료하려면 "종료"를 입력해주세요.)
# 챗봇: 멋진 실습이네요. 랭체인으로 부동산 KB를 다루는 챗봇을 만들 때의 기본 흐름과 바로 따라할 수 있는 가이드라인을 정리해 드릴게요. 제공하신 자료(예: 그림Ⅲ-17 GTX-A 노선 조기 개통 추진 현황, 3기 신도시 등)처럼 도메인 문서를 다루는 QA 봇으로 구성하는 것을 목표로 하면 좋습니다.
#
# 1) 기본 설계 방향
# - 목적 정의: 경기 남부권 반도체 클러스터/GTX-A 노선 관련 실무 질의에 대해 신뢰 가능한 출처를 근거로 답변하고, 필요 시 출처를 함께 제시.
# - 데이터 범위: 제공된 보고서·자료(PDF/Text) 및 요약 노트 등을 문서로 수집하고 카테고리(Tag)별로 정리.
# - 응답 형식: 간단 요약 vs 상세 설명 중 선택 가능. 항상 출처를 표시하도록 설계.
# - 다중-turn 대화: “출처 확인 → 요약 → 추가 정보 질의” 같은 흐름으로 대화 유지.
#
# 2) 데이터 준비 및 인덱싱
# - 문서 수집: 그림 제목, 그림 번호(예: 그림Ⅲ-17), 부제목, 핵심 수치 등을 태깅.
# - 텍스트 추출/정제: PDF에서 텍스트 추출 시 표/도표는 텍스트 요약으로 대체하되 원문 출처를 남김.
# - 메타데이터 추가: 출처 문서명, 섹션, 그림 번호, 날짜, 담당 부서 등.
# - 벡터 상에 인덱싱: 임베딩을 만들어 벡터 스토어에 저장.
#
# 3) 기술 스택 구성(간단한 예)
# - 텍스트 인덱싱 및 검색: LangChain + 벡터 스토어(예: FAISS)
# - 임베딩 모델: 한국어에 잘 맞는 모델 또는 OpenAI의 텍스트 임베딩
# - LLM: 한국어를 잘 이해하는 모델(OpenAI의 gpt-4/gpt-3.5-turbo 등 또는 로컬 모델)
# - 대화 체인: RetrievalQA(혹은 chat 기반 대화 체인)로 질의-응답
# - 예시 구성 흐름
#   - 문서 로더 → 임베딩 → 벡터 스토어 생성
#   - RetrievalQA 또는 Chat 기반 체인에 벡터 리트리버 연결
#   - 사용자가 질의하면 벡터 리트리버로 관련 문서를 찾고, LLM이 요약·응답
#   - 응답에 출처 표기
#
# 4) 권장 프롬프트 설계 포인트
# - 한국어 프롬프트 예시 포맷:
#   - 질의에 대한 직접 답: “ GTX-A 노선 조기 개통 현황은 무엇인가요? 상세 현황과 최근 추진 상황을 포함해 요약해 주세요. 출처를 함께 표시해 주세요.”
#   - 출력 형식 제어: “요약형(짧은 한 문장) / 상세형(핵심 포인트 3~5개) 중 선택 가능”
#   - 출처 인용 방식: “출처: [그림Ⅲ-17], [문서명/섹션]”
#   - 한계 명시: “해당 자료의 날짜를 기준으로 한 정보입니다. 최신 업데이트가 필요하면 재조회해 주세요.”
# - 도메인 힌트 포함: GTX-A, 3기 신도시, 공공 공급 활성화, 부집중도 지수 등 키워드를 프롬프트에 링크
#
# 5) 간단한 샘플 코드 스켈레톤
# 참고용으로 간단한 구조를 보여드립니다. 실제 환경에 맞춰 키/모델 이름 등을 바꾸세요.
#
# - 필요 패키지 설치 예: pip install langchain openai faiss-cpu
#
# - 파이프라인 구성 예(파이썬)
#   - 주의: 파일 경로/모델 이름은 환경에 맞게 변경 필요
#
#   from langchain.document_loaders import DirectoryLoader
#   from langchain.embeddings import OpenAIEmbeddings
#   from langchain.vectorstores import FAISS
#   from langchain.chains import RetrievalQA
#   from langchain.llms import OpenAI
#
#   # 1) 문서 로딩 (예: /path/to/real_estate_kb에 txt/pdf가 모여 있음)
#   loader = DirectoryLoader('/path/to/real_estate_kb', glob="**/*")
#   docs = loader.load()
#
#   # 2) 임베딩 + 벡터 스토어 생성
#   embeddings = OpenAIEmbeddings(model="text-embedding-001")  # 또는 нуж 모델명
#   vector_store = FAISS.from_documents(docs, embeddings)
#
#   # 3) QA 체인 구성
#   qa = RetrievalQA.from_chain_type(
#       llm=OpenAI(model_name="gpt-4", temperature=0.0),
#       chain_type="stuff",                   # 필요 시 "map_rerank" 등으로 변경
#       retriever=vector_store.as_retriever()
#   )
#
#   # 4) 질의 예
#   query = "GTX-A 노선 조기 개통 현황은?"
#   answer = qa.run(query)
#   print(answer)
#
# - 대화형/추가 기능 예(간단)
#   - 대화 히스토리 유지가 필요하면 ChatOpenAI + ConversationChain 등으로 확장
#   - 출력에 출처를 포함하도록 프롬프트를 조정하거나, chain의 결과에 출처를 함께 포맷하는 래퍼를 추가
#
# 6) 운영/평가 팁
# - 출처 표시 강제: 답변에 항상 출처를 덧붙이도록 프롬프트나 체인 설정을 구성
# - 최신성 관리: 주기적으로 문서를 업데이트하고 재인덱싱
# - 품질 점검: 1) 비슷한 주제에 대해 일관성 있는 답변 2) 모르는 질의에 대해 “관련 문서를 찾지 못했습니다”와 같은 안전한 응답
# - 다국어/한국어 최적화: 한국어 문서에 맞춰 임베딩/LLM 설정을 최적화하고, 필요한 경우 한국어-전용 모델 사용
#
# 7) 밑그림 완성 전 확인하고 싶은 것
# - 어떤 데이터 소스를 우선 사용할지(예: 그림Ⅲ-17 포함 문서 vs. 3기 신도시 관련 자료)
# - 배포 환경(GPT API 키 사용 여부, 서버 배포 여부)
# - 원하는 응답 형식(간단 요약/상세 요약, 출처 포함 여부)
# - 한국어 최적화를 위한 모델 선호 여부
#
# 원하시면 지금 바로 간단한 샘플 코드와 프롬프트 템플릿을 구체적으로 맞춰 드릴게요. 사용하시는 환경(API 키 여부, 로컬/클라우드, 선호 모델 등)을 알려주시면 그에 맞춰 맞춤형 예제를 드리겠습니다.
# 챗봇: 요약드리면, KB의 2024년 수도권 주택 매매가격 전망은 다음과 같습니다.
#
# - 수도권 전망: 상승을 전망하는 비율은 전체의 약 1/3(약 33%) 수준으로 나타났습니다. 나머지는 하락 또는 보합으로 보는 관측이 많아, 수도권은 전국 평균 대비 역시 상승 기대가 다소 제한적이고 하락 전망이 더 우세한 편으로 보입니다.
# - 맥락: 전체적으로는 하락 전망이 많은 상황에서, 시장 여건 개선에 대한 기대감이 반영되어 수도권에서도 상승 가능성을 1/3 정도로 제시한 것이 특징입니다.
# - 비교 포인트(참고): 비수도권의 경우 전문가 88%가 하락을 전망했고, 공인중개사는 70%가 하락을 전망하는 등 비수도권은 하락 측 응답이 더 강합니다. 하락폭에 대해서도 전문가의 51%가 3% 이상 하락을 예상한 반면, 공인중개사는 28%에 그쳤습니다.
#
# 참고 출처: KB경영연구소, 그림Ⅱ-1(2024년 전국 주택 매매가격 전망) 및 그림Ⅱ-2의 지역별 전망 자료 포함.
#
# 추가로 원하시면
# - 수도권의 구체적 수치(예: 상승/하락 비율의 구체치)와 그림Ⅱ-1의 세부 수치를 함께 정리해 드리겠습니다.
# - 혹은 이 정보를 바탕으로 요약 보고서나 프롬프트 템플릿도 만들어 드릴 수 있습니다.
# 챗봇: 좋아요. 다만 “구로구 개봉역 인근의 현재 상태와 미래 호재”를 정확히 전달하려면 해당 지역의 최신 자료를 확인해야 합니다. 현재 대화에 포함된 KB 보고서의 구로구 개봉역 관련 구체적 수치나 호재 항목은 명시돼 있지 않아, 아래와 같은 방식으로 먼저 확인하고 정리해 드리겠습니다.
#
# 제가 제공할 수 있는 두 가지 접근 방식
# - 방법 A: 제공하신 자료(또는 KB 2024 수도권 보고서)에서 구로구 개봉역 인근 섹션을 찾아 현재 상태와 예측 호재를 직접 요약
# - 방법 B: 보유 데이터를 바탕으로 일반적인 역세권 분석 프레임으로 예측 요약(데이터가 없더라도, 교통 호재, 재개발, 인프라 확충 등으로 구성)
#
# 권장 구성 포맷 (원하시면 이대로 정리해 드립니다)
# 1) 현재 상태 요약
# - 위치와 교통: 개봉역 인근의 역세권 접근성, 도보/도시철도 연결성
# - 주거환경: 인프라(상권, 학교, 병원, 공원 등), 주택 유형과 교통 편의성에 따른 프리미엄 여부
# - 최근 거래 흐름: 매매가/전세가의 최근 추이(가능하면 전용면적 84m2 기준 가격대)
# - 공급/수요 상황: 신규 입주 물량 여부, 임대 수요의 강도
#
# 2) 미래 호재(개봉역 인근에 영향을 줄 수 있는 개발/정책 요소)
# - 교통 호재: 새로운 노선/정거장, GTX 연계, 도시철도 연장 계획, 버스 노선 개선 등
# - 개발 호재: 재개발/재건축 추진 여부, 역세권 개발, 대규모 상업·업무시설 조성 계획
# - 인프라 확충: 학교, 병원, 공공시설 확충 계획
# - 정책/시장 요인: 지자체 주택공급 계획, 인센티브, 분양가 관리 등
# - 리스크 포인트: 개발 속도 지연 가능성, 금리/정책 변수의 영향
#
# 3) 간단한 수치 예시 포맷(데이터 확보 시 포함)
# - 최근 1년 매매가 변화율: 예) 전용 84m2 기준 X% 상승/하락
# - 최근 전세가 변화율: 예) 전용 84m2 기준 Y% 상승/하락
# - 예정 호재의 시점: 예) 2026년 말 개통 예고 등
#
# 다음 중 어떤 방식으로 진행할지 알려주시면 바로 진행해 드리겠습니다
# - A: 현재 자료에서 구로구 개봉역 관련 섹션을 찾아 구체 수치와 출처를 바탕으로 요약
# - B: 제가 보유하고 있는 일반 프레임으로 개봉역 인근의 현재 상태와 가능성 있는 호재를 이론적으로 정리(데이터 부재 시 추정치 포함)
# - 또는 자료를 공유해 주시면 그 자료를 바로 분석해 요약본을 드리겠습니다(PDF 링크나 텍스트를 붙여주셔도 됩니다)
#
# 참고로, 구로구 개봉역 인근의 구체적인 수치나 개발 일정은 금리·정책 변화에 따라 달라질 수 있으니 최신 자료로 재확인하는 것을 권합니다. 필요하시면 제가 곧바로 해당 지역의 자료를 찾아 요약해 드리겠습니다.
