# %%
import logging
from copy import deepcopy

from langchain_community.document_loaders import TextLoader
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_classic.storage import InMemoryStore
from langchain_classic.retrievers.parent_document_retriever import ParentDocumentRetriever
from langchain_classic.retrievers.multi_query import MultiQueryRetriever
from langchain_chroma import Chroma
from langchain_openai import ChatOpenAI
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_classic.chains import RetrievalQA

# %%
embeddings = HuggingFaceEmbeddings(model='BAAI/bge-m3', model_kwargs={'device':'cuda'}, encode_kwargs={'batch_size':8})
model = ChatOpenAI(model='gpt-5-mini', temperature=0.2)

# %%
loaders = [TextLoader('./data/How_to_invest_money.txt', encoding='utf-8')]
docs = []
for loader in loaders:
    docs.extend(loader.load())

# %%
parent_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
child_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=50)

# %%
vectorstore = Chroma(collection_name='split_parents', embedding_function=embeddings)
docstore = InMemoryStore()

# %%
pc_retriever = ParentDocumentRetriever(
    docstore=docstore,
    vectorstore=vectorstore,
    parent_splitter=parent_splitter,
    child_splitter=child_splitter
)

pc_retriever.add_documents(docs)

# %%
print(len(list(docstore.yield_keys())))
print(vectorstore._collection.count())
# Out:
# 219
# 1148

# %%
query = 'What are the types of investments?'
retrieved_docs = pc_retriever.invoke(query)
print(retrieved_docs[0].page_content)
print('--'*30)
sub_docs = vectorstore.similarity_search(query)
print(sub_docs[0].page_content)
# Out:
# There are five chief points to be considered in the selection of all
# forms of investment. These are: (1) safety of principal and interest;
# (2) rate of income; (3) convertibility into cash; (4) prospect of
# appreciation in intrinsic value; (5) stability of market price.
#
# Keeping these five general factors in mind, the present chapter will
# discuss real-estate mortgages as a form of investment, both as adapted
# to the requirements of private funds and of a business surplus.
# ------------------------------------------------------------
# There are five chief points to be considered in the selection of all
# forms of investment. These are: (1) safety of principal and interest;

# %%
logging.basicConfig()
logging.getLogger('langchain_classic.retrievers.multi_query').setLevel(logging.INFO)

# %%
mq_retriever = MultiQueryRetriever.from_llm(
    retriever=pc_retriever,
    llm=model
)

# %%
question = '주식 투자를 처음 시작하려면 어떻게 해야 하나요?'
unique_docs = mq_retriever.invoke(question)
print(f'{len(unique_docs)}개의 문서가 검색되었습니다.')
# Out:
# INFO:langchain_classic.retrievers.multi_query:Generated queries: ['주식 투자를 처음 시작하려면 어떤 준비와 절차가 필요하나요?', '초보자가 주식 투자를 시작할 때 알아야 할 기본 지식, 계좌 개설 방법, 추천 학습 자료는 무엇인가요?', '소액으로 주식 투자를 처음 시작할 때의 실전 투자 방법과 리스크 관리 요령을 알려주세요.']
# 7개의 문서가 검색되었습니다.

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=model,
    retriever=mq_retriever,
    chain_type='stuff',
    return_source_documents=True
)

# %%
result = qa_chain.invoke({'query':question})
print(result['result'])
# Out:
# INFO:langchain_classic.retrievers.multi_query:Generated queries: ['주식 투자를 처음 시작하는 초보자가 준비해야 할 단계와 필수 지식은 무엇인가요?', '주식 계좌 개설부터 첫 매수까지 실제로 따라할 수 있는 초보자용 가이드는?', '초보 투자자가 알아야 할 리스크 관리 방법, 종목 선정 기준 및 공부 자료 추천은?']
# 좋습니다 — 주식 투자를 처음 시작할 때 따라야 할 실용적이고 현실적인 단계들을 요약해 드리겠습니다. 아래 순서대로 하면 초보자의 실수 위험을 줄이고 장기적으로 안정적으로 자산을 키울 가능성을 높일 수 있습니다.
#
# 1) 투자 목적과 기간, 위험성향 정하기
# - 목적(예: 은퇴자금, 주택마련, 단기수익)과 투자기간을 분명히 하세요.
# - 감당할 수 있는 손실 수준(위험성향)을 미리 정해야 투자 스타일(공격형·중립형·안전형)이 나옵니다.
#
# 2) 기초 개념 이해하기 (주식과 채권의 차이 포함)
# - 주식: 회사의 지분. 배당·주가 상승은 기대할 수 있으나 원금 보장 없음.
# - 채권: 채무증서. 이자·원금 상환 약속(만기)이 있어 보통 안전성이 높음.
# - 투자 선택 시 고려할 5가지(책에서 제시된 핵심 기준): 원금 및 이자(배당)의 안전성, 수익률, 현금화(유동성), 내재가치의 상승 가능성, 시장가격의 안정성.
#
# 3) 기초 재무지식과 기업 분석법 배우기
# - 손익계산서·대차대조표·현금흐름표의 기본 항목을 익히세요.
# - P/E(주가수익비율), P/B, 배당수익률, 부채비율 같은 핵심 지표를 이해하세요.
# - 기업의 사업모델·경쟁우위·성장성·배당역사 등을 확인하세요.
#
# 4) 분산투자와 포트폴리오 구성
# - 개별주에 몰빵하지 마세요. 업종·지역·자산(주식·채권)으로 분산하세요.
# - 초보는 개별주보다 ETF(지수추종 상장지수펀드)나 인덱스펀드로 시작하는 것이 안전하고 비용효율적입니다.
#
# 5) 계좌 개설과 실전 준비
# - 신뢰할 수 있는 증권사(수수료·거래플랫폼·고객지원·세제혜택 등 고려)에서 계좌를 만드세요.
# - 비상금(생활비 3~6개월)과 고금리 부채 상환을 먼저 하고 남은 여유자금으로 투자하세요.
# - 처음엔 적은 금액으로 시작해 경험을 쌓으세요(달러코스트에버리징 추천).
#
# 6) 리스크 관리 원칙 지키기
# - 레버리지(빚내서 투자), 마진거래는 초반에 피하세요.
# - 포지션 크기 제한, 손절 규칙 등 본인만의 규율을 만드세요.
# - 포트폴리오 정기 점검(예: 6~12개월)과 리밸런싱을 시행하세요.
#
# 7) 정보 습득과 심리 관리
# - 뉴스·기업공시·애널리스트 리포트 등을 보되 과도한 단기시세에 휩쓸리지 마세요.
# - 투자 성과는 장기적 관점에서 평가하세요. 단기 변동성은 자연스러운 현상입니다.
#
# 8) 실무적 대안 및 도움받기
# - 직접 운용이 부담스럽다면 로보어드바이저나 자산운용사 모델 포트폴리오를 이용하세요.
# - 필요하면 재무상담가·세무사 등 전문가에게 상담을 받으세요.
#
# 원하시면 다음을 도와드릴 수 있습니다: 현재 재무상태(목적·기간·예산)를 알려주시면 초보자용 포트폴리오 예시(ETF 중심)나 첫 종목(또는 펀드) 선택 기준을 구체적으로 제안해 드리겠습니다. 어떤 도움을 원하시나요?

# %%
def format_docs(docs):
    return '\n\n'.join(doc.page_content for doc in docs)

# %%
def create_virtual_doc_chain():
    system = '당신은 고도로 숙련된 AI입니다. 질문에 맞도록 적절하게 행동하세요.'
    user = '''
    주어진 질문 "{query}"에 대해 직접적으로 답변하는 가상의 문서를 생성하세요.
    문서의 크기는 {chunk_size} 언저리여야 합니다.
    해당 답변은 추후 다시 질문하는데 쓰일 예정임을 참고하세요.'''

    prompt = ChatPromptTemplate.from_messages(
        [('system', system),
         ('human', user)]
    )

    return prompt | model | StrOutputParser()

# %%
def create_retrieval_chain():
    return RunnableLambda(lambda x: mq_retriever.invoke(x['virtual_doc']))

# %%
def create_final_response_chain():
    template = '''다음 정보와 질문을 바탕으로 답변해주세요.
    컨텍스트: {context}
    질문: {question}
    답변:
    '''
    final_prompt = ChatPromptTemplate.from_template(template)

    return final_prompt | model | StrOutputParser()

# %%
def print_input_output(input_data, output_data, step_name):
    print(f'\n--- {step_name} ---')
    print(f'Input: {input_data}')
    print(f'Output: {output_data}')
    print('-' * 50)

# %%
def create_pipeline_with_logging():
    virtual_doc_chain = create_virtual_doc_chain()
    retrieval_chain = create_retrieval_chain()
    final_response_chain = create_final_response_chain()

    def virtual_doc_step(x):
        result = {'virtual_doc':virtual_doc_chain.invoke({'query':x['question'], 'chunk_size':200})}
        print_input_output(x, result, 'Virtual Doc Generation')
        return {**x, **result}
    
    def retrieval_step(x):
        result = {'retrieved_docs':retrieval_chain.invoke(x)}
        print_input_output(x, result, 'Document Retrieval')
        return {**x, **result}
    
    def context_formatting_step(x):
        result = {'context':format_docs(x['retrieved_docs'])}
        print_input_output(x, result, 'Context Formatting')
        return {**x, **result}
    
    def final_response_step(x):
        result = final_response_chain.invoke(x)
        print_input_output(x, result, 'Final Response Generation')
        return result
    
    pipeline = (
        RunnableLambda(virtual_doc_step)
        | RunnableLambda(retrieval_step)
        | RunnableLambda(context_formatting_step)
        | RunnableLambda(final_response_step)
    )

    return pipeline

# %%
pipeline = create_pipeline_with_logging()

# %%
question = '주식 시장의 변동성이 높을 때 투자 전략은 무엇인가요?'
response = pipeline.invoke({'question':question})
print(response)
# Out:
# --- Virtual Doc Generation ---
# Input: {'question': '주식 시장의 변동성이 높을 때 투자 전략은 무엇인가요?'}
# Output: {'virtual_doc': '주식 시장의 변동성이 높을 때는 포트폴리오 다각화, 현금 비중 확보, 정기적 리밸런싱, 분할매수(달러코스트에버리징), 방어적 섹터·고배당 종목 비중 확대, 손절 규칙 설정, 파생상품으로 헤지, 장기 관점 유지와 감정 통제가 핵심입니다. 리스크 허용범위 재점검과 수수료·세금 고려도 필수입니다.'}
# --------------------------------------------------
# INFO:langchain_classic.retrievers.multi_query:Generated queries: ['주식 시장 변동성이 높을 때 포트폴리오 관리에 적용할 실무 전략(다각화·현금 비중·정기적 리밸런싱·분할매수·방어섹터·고배당 비중 확대·손절 규칙·파생상품 헤지·장기 관점·감정 통제)과 단계별 체크리스트가 포함된 자료가 있나요?', '변동성 장에서 각 전략의 효과성과 근거를 비교한 연구·사례 자료(달러코스트에버리징, 리밸런싱 빈도, 고배당·방어섹터의 방어력, 파생상품 헤지의 비용·효과 등)를 추천해 주세요.', '리스크 허용범위 재점검 방법, 손절 기준 설정 규칙, 리밸런싱 빈도 결정법 및 수수료·세금이 포트폴리오 성과에 미치는 영향을 분석한 보고서나 실습용 계산 예제가 있는 문서를 찾고 싶습니다.']
# --- Document Retrieval ---
# Input: {'question': '주식 시장의 변동성이 높을 때 투자 전략은 무엇인가요?', 'virtual_doc': '주식 시장의 변동성이 높을 때는 포트폴리오 다각화, 현금 비중 확보, 정기적 리밸런싱, 분할매수(달러코스트에버리징), 방어적 섹터·고배당 종목 비중 확대, 손절 규칙 설정, 파생상품으로 헤지, 장기 관점 유지와 감정 통제가 핵심입니다. 리스크 허용범위 재점검과 수수료·세금 고려도 필수입니다.'}
# Output: {'retrieved_docs': [Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='For the successful investment of money, however, a good deal more is\nrequired than the mere ability to select a safe security. That is only\none phase of the problem. Scientific investment demands a clear\nunderstanding of the fundamental distinctions between different classes\nof securities and strict adherence to the two cardinal principles,\ndistribution of risk and selection of securities in accordance with\nreal requirements.'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='It is plainly impossible within the limits of a small volume to consider\nthe needs of all classes of investors. Special attention will be paid to\nthe requirements of a business surplus and of the private investor. In\nthe field of private investment two distinct classes can be\nrecognized--those who are dependent upon income from investments and\nthose who are not. Both classes will be considered. For the investment\nof a business surplus, safety, convertibility, and stability of price\nare the qualities to be emphasized; for investors dependent upon income,\nsafety and a high return; and for those not dependent upon income, a\nhigh return and prospect of appreciation in value. In the following\nchapters railroad bonds, real-estate mortgages, industrial,\npublic-utility, and municipal bonds and stocks will be considered in\nturn; their advantages and disadvantages will be analyzed in accordance\nwith the determining qualities above enumerated, and their adaptability'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='(_b_) _Net quick assets._ The balance-sheet of every industrial company\ncan be divided horizontally into two parts. Its assets are of two\nkinds--property assets, which are fixt, and current assets, which are\nfluid. Similarly, its liabilities are of two kinds--capital liabilities\nand current liabilities. It requires no very extended business\nexperience to pick out the items which make up these totals. Plant and\nproperty assets are usually lumped together under the head, "Cost of\nProperty." Current assets include inventories, bills and accounts\nreceivable, agents\' balances, marketable securities, and cash on hand\nand in banks--everything, in short, which can be quickly converted into\ncash. On the other side of the balance-sheet, capital liabilities are\neasily determined. They consist of the par amounts of bonds and stocks\noutstanding. Current liabilities comprise bills and accounts payable,\nincluding borrowed money, pay-rolls, and interest and taxes accrued but\nnot due.'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='After learning how to judge the value of every form of investment, a man\nmay still be unsuccessful in the investment of money unless he acquires\nalso a firm grasp upon the general principles which control the price\nmovements of securities. By this it is not meant that a man needs to\nhave an intimate knowledge of technical market conditions whereby to\nestimate temporary fluctations of minor importance, but rather that he\nshould have clearly in mind the causes which operate to produce the\nlarger swings of prices. If an investor acquires such a knowledge, he is\nenabled to take advantage of large price movements in such a way as\nmaterially to increase his income, and, at the same time, avoid\ncarrying upon his books securities which may have cost much more than\ntheir current market quotations. If he can recognize the indications\nwhich point to the beginning of a pronounced upward swing in securities,\nand if he can equally recognize the signs which indicate that the'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='VII\n\nMUNICIPAL BONDS\n\n\nThe previous chapters have considered, in turn, the investment value of\nrailroad bonds, real-estate mortgages, industrial bonds, and\npu ...
# --------------------------------------------------
#
# --- Context Formatting ---
# Input: {'question': '주식 시장의 변동성이 높을 때 투자 전략은 무엇인가요?', 'virtual_doc': '주식 시장의 변동성이 높을 때는 포트폴리오 다각화, 현금 비중 확보, 정기적 리밸런싱, 분할매수(달러코스트에버리징), 방어적 섹터·고배당 종목 비중 확대, 손절 규칙 설정, 파생상품으로 헤지, 장기 관점 유지와 감정 통제가 핵심입니다. 리스크 허용범위 재점검과 수수료·세금 고려도 필수입니다.', 'retrieved_docs': [Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='For the successful investment of money, however, a good deal more is\nrequired than the mere ability to select a safe security. That is only\none phase of the problem. Scientific investment demands a clear\nunderstanding of the fundamental distinctions between different classes\nof securities and strict adherence to the two cardinal principles,\ndistribution of risk and selection of securities in accordance with\nreal requirements.'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='It is plainly impossible within the limits of a small volume to consider\nthe needs of all classes of investors. Special attention will be paid to\nthe requirements of a business surplus and of the private investor. In\nthe field of private investment two distinct classes can be\nrecognized--those who are dependent upon income from investments and\nthose who are not. Both classes will be considered. For the investment\nof a business surplus, safety, convertibility, and stability of price\nare the qualities to be emphasized; for investors dependent upon income,\nsafety and a high return; and for those not dependent upon income, a\nhigh return and prospect of appreciation in value. In the following\nchapters railroad bonds, real-estate mortgages, industrial,\npublic-utility, and municipal bonds and stocks will be considered in\nturn; their advantages and disadvantages will be analyzed in accordance\nwith the determining qualities above enumerated, and their adaptability'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='(_b_) _Net quick assets._ The balance-sheet of every industrial company\ncan be divided horizontally into two parts. Its assets are of two\nkinds--property assets, which are fixt, and current assets, which are\nfluid. Similarly, its liabilities are of two kinds--capital liabilities\nand current liabilities. It requires no very extended business\nexperience to pick out the items which make up these totals. Plant and\nproperty assets are usually lumped together under the head, "Cost of\nProperty." Current assets include inventories, bills and accounts\nreceivable, agents\' balances, marketable securities, and cash on hand\nand in banks--everything, in short, which can be quickly converted into\ncash. On the other side of the balance-sheet, capital liabilities are\neasily determined. They consist of the par amounts of bonds and stocks\noutstanding. Current liabilities comprise bills and accounts payable,\nincluding borrowed money, pay-rolls, and interest and taxes accrued but\nnot due.'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='After learning how to judge the value of every form of investment, a man\nmay still be unsuccessful in the investment of money unless he acquires\nalso a firm grasp upon the general principles which control the price\nmovements of securities. By this it is not meant that a man needs to\nhave an intimate knowledge of technical market conditions whereby to\nestimate temporary fluctations of minor importance, but rather that he\nshould have clearly in mind the causes which operate to produce the\nlarger swings of prices. If an investor acquires such a knowledge, he is\nenabled to take advantage of large price movements in such a way as\nmaterially to increase his income, and, at the same time, avoid\ncarrying upon his books securities which may have cost much more than\ntheir current market quotations. If he can recognize the indications\nwhich point to the beginning of a pronounced upward swing in securities,\nand if he can equally recognize the signs which indicate that the'), Document(metadat ...
# Output: {'context': 'For the successful investment of money, however, a good deal more is\nrequired than the mere ability to select a safe security. That is only\none phase of the problem. Scientific investment demands a clear\nunderstanding of the fundamental distinctions between different classes\nof securities and strict adherence to the two cardinal principles,\ndistribution of risk and selection of securities in accordance with\nreal requirements.\n\nIt is plainly impossible within the limits of a small volume to consider\nthe needs of all classes of investors. Special attention will be paid to\nthe requirements of a business surplus and of the private investor. In\nthe field of private investment two distinct classes can be\nrecognized--those who are dependent upon income from investments and\nthose who are not. Both classes will be considered. For the investment\nof a business surplus, safety, convertibility, and stability of price\nare the qualities to be emphasized; for investors dependent upon income,\nsafety and a high return; and for those not dependent upon income, a\nhigh return and prospect of appreciation in value. In the following\nchapters railroad bonds, real-estate mortgages, industrial,\npublic-utility, and municipal bonds and stocks will be considered in\nturn; their advantages and disadvantages will be analyzed in accordance\nwith the determining qualities above enumerated, and their adaptability\n\n(_b_) _Net quick assets._ The balance-sheet of every industrial company\ncan be divided horizontally into two parts. Its assets are of two\nkinds--property assets, which are fixt, and current assets, which are\nfluid. Similarly, its liabilities are of two kinds--capital liabilities\nand current liabilities. It requires no very extended business\nexperience to pick out the items which make up these totals. Plant and\nproperty assets are usually lumped together under the head, "Cost of\nProperty." Current assets include inventories, bills and accounts\nreceivable, agents\' balances, marketable securities, and cash on hand\nand in banks--everything, in short, which can be quickly converted into\ncash. On the other side of the balance-sheet, capital liabilities are\neasily determined. They consist of the par amounts of bonds and stocks\noutstanding. Current liabilities comprise bills and accounts payable,\nincluding borrowed money, pay-rolls, and interest and taxes accrued but\nnot due.\n\nAfter learning how to judge the value of every form of investment, a man\nmay still be unsuccessful in the investment of money unless he acquires\nalso a firm grasp upon the general principles which control the price\nmovements of securities. By this it is not meant that a man needs to\nhave an intimate knowledge of technical market conditions whereby to\nestimate temporary fluctations of minor importance, but rather that he\nshould have clearly in mind the causes which operate to produce the\nlarger swings of prices. If an investor acquires such a knowledge, he is\nenabled to take advantage of large price movements in such a way as\nmaterially to increase his income, and, at the same time, avoid\ncarrying upon his books securities which may have cost much more than\ntheir current market quotations. If he can recognize the indications\nwhich point to the beginning of a pronounced upward swing in securities,\nand if he can equally recognize the signs which indicate that the\n\nVII\n\nMUNICIPAL BONDS\n\n\nThe previous chapters have considered, in turn, the investment value of\nrailroad bonds, real-estate mortgages, industrial bonds, and\npublic-utility bonds. The desirability of each of these different\nclasses of security has been judged in accordance with the general\nprinciples laid down in the introductory chapter; that is to say, each\nclass has been analyzed in relation to safety, rate of income,\nconvertibility, prospect of appreciation in value and stability of\nmarket price. The same determining factors must now be appli ...
# --------------------------------------------------
#
# --- Final Response Generation ---
# Input: {'question': '주식 시장의 변동성이 높을 때 투자 전략은 무엇인가요?', 'virtual_doc': '주식 시장의 변동성이 높을 때는 포트폴리오 다각화, 현금 비중 확보, 정기적 리밸런싱, 분할매수(달러코스트에버리징), 방어적 섹터·고배당 종목 비중 확대, 손절 규칙 설정, 파생상품으로 헤지, 장기 관점 유지와 감정 통제가 핵심입니다. 리스크 허용범위 재점검과 수수료·세금 고려도 필수입니다.', 'retrieved_docs': [Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='For the successful investment of money, however, a good deal more is\nrequired than the mere ability to select a safe security. That is only\none phase of the problem. Scientific investment demands a clear\nunderstanding of the fundamental distinctions between different classes\nof securities and strict adherence to the two cardinal principles,\ndistribution of risk and selection of securities in accordance with\nreal requirements.'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='It is plainly impossible within the limits of a small volume to consider\nthe needs of all classes of investors. Special attention will be paid to\nthe requirements of a business surplus and of the private investor. In\nthe field of private investment two distinct classes can be\nrecognized--those who are dependent upon income from investments and\nthose who are not. Both classes will be considered. For the investment\nof a business surplus, safety, convertibility, and stability of price\nare the qualities to be emphasized; for investors dependent upon income,\nsafety and a high return; and for those not dependent upon income, a\nhigh return and prospect of appreciation in value. In the following\nchapters railroad bonds, real-estate mortgages, industrial,\npublic-utility, and municipal bonds and stocks will be considered in\nturn; their advantages and disadvantages will be analyzed in accordance\nwith the determining qualities above enumerated, and their adaptability'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='(_b_) _Net quick assets._ The balance-sheet of every industrial company\ncan be divided horizontally into two parts. Its assets are of two\nkinds--property assets, which are fixt, and current assets, which are\nfluid. Similarly, its liabilities are of two kinds--capital liabilities\nand current liabilities. It requires no very extended business\nexperience to pick out the items which make up these totals. Plant and\nproperty assets are usually lumped together under the head, "Cost of\nProperty." Current assets include inventories, bills and accounts\nreceivable, agents\' balances, marketable securities, and cash on hand\nand in banks--everything, in short, which can be quickly converted into\ncash. On the other side of the balance-sheet, capital liabilities are\neasily determined. They consist of the par amounts of bonds and stocks\noutstanding. Current liabilities comprise bills and accounts payable,\nincluding borrowed money, pay-rolls, and interest and taxes accrued but\nnot due.'), Document(metadata={'source': './data/How_to_invest_money.txt'}, page_content='After learning how to judge the value of every form of investment, a man\nmay still be unsuccessful in the investment of money unless he acquires\nalso a firm grasp upon the general principles which control the price\nmovements of securities. By this it is not meant that a man needs to\nhave an intimate knowledge of technical market conditions whereby to\nestimate temporary fluctations of minor importance, but rather that he\nshould have clearly in mind the causes which operate to produce the\nlarger swings of prices. If an investor acquires such a knowledge, he is\nenabled to take advantage of large price movements in such a way as\nmaterially to increase his income, and, at the same time, avoid\ncarrying upon his books securities which may have cost much more than\ntheir current market quotations. If he can recognize the indications\nwhich point to the beginning of a pronounced upward swing in securities,\nand if he can equally recognize the signs which indicate that the'), Document(metadat ...
# Output: 좋은 질문입니다. 주식 시장의 변동성이 클 때는 “무엇을 사고파는가”뿐 아니라 “왜, 언제,얼마나”라는 투자 목적과 규칙을 엄격히 지키는 것이 더 중요합니다. 주어진 컨텍스트의 핵심 원칙(위험 분산, 투자목적에 맞는 증권선택, 큰 가격변동의 원인 이해)을 바탕으로 실용적 전략을 정리하면 다음과 같습니다.
#
# 공통 원칙(모든 투자자)
# - 위험 분산(포트폴리오 분산)을 강화: 자산(주식·채권·현금·대체투자)에 걸쳐 분산하여 개별 종목·섹터 리스크 완화.
# - 투자목적·시간수평·위험허용도 재확인: 단기 유동성 필요인지, 배당(소득) 의존인지, 장기 자본이득 목표인지에 따라 대응이 달라짐.
# - 현금(혹은 현금성자산) 확보: 급락 시 기회 구매용 또는 비상시 현금 필요 충족.
# - 기본(펀더멘털)에 집중: 좋은 기업의 수익성·부채·현금흐름 등 기초체력을 점검. 일시적 변동과 근본적 악화(실적·산업 구조 변화)를 구분.
# - 계획 준수: 미리 정한 자산배분·리밸런싱 규칙과 손절·목표매수 규칙을 마련하고 감정적 매매를 피함.
#
# 투자자 유형별 권장 전략
# - 사업 잉여금(기업의 여유자금): 안전·전환성·가격안정성이 핵심. 단기·중기 국채·우량 회사채·고품질 단기 상품·우량 단기 투자등급 채권·현금 비중 확대. 주식 비중 축소 권장.
# - 투자소득에 의존하는 개인: 안전성과 충분한 수익률 동시 확보. 배당 우량주·투자등급 채권·지속 가능한 배당 ETF·우선주 등으로 방어적 포트폴리오 구성. 변동성 큰 종목은 비중 축소.
# - 소득에 의존하지 않는 장기 투자자(성장 중시): 변동성은 매수 기회로 활용 가능. DCA(정액투자)로 가격 평균화, 우수 성장주·업종별 분산 매수, 단기 노이즈에 흔들리지 않도록 장기계획 유지.
#
# 전술적 수단(리스크 관리)
# - 리밸런싱: 자산배분이 깨지면 규칙적으로 되돌림(매도·매수).
# - 달러 코스트 애버리징(DCA): 변동성 큰 시기에 일시적으로 큰 금액 투자 위험을 줄임.
# - 헤지: 필요시 포트폴리오 일부에 옵션(보호풋)·인버스 상품 등으로 하방 위험 관리(복잡하므로 이해가 있을 때만).
# - 레버리지·마진 축소: 변동성 클 때 레버리지는 손실 증폭. 가능한 한 줄임.
# - 주문 방식 활용: 시장가 대신 지정가·분할매수로 급격한 슬리피지 방지.
#
# 심리적·실무적 조언
# - 단기 잡음에 과민 반응하지 말 것. 큰 가격 움직임의 원인(거시·정책·유동성 변화 등)을 이해하려 노력.
# - 포트폴리오와 목표가 일치하지 않다면 재설계할 것.
# - 필요하면 전문가(재무설계사·투자전문가)와 상담.
#
# 요약: 변동성은 리스크이자 기회입니다. 핵심은 분산·유동성 확보·투자목적에 맞는 안전성 선택과, 사전에 세운 규칙을 감정 없이 지키는 것입니다. 필요하면 귀하의 투자목적(예: 단기 유동성 필요 여부, 소득 의존도, 투자기간)을 알려주시면 보다 구체적인 포트폴리오 제안을 드리겠습니다.
# --------------------------------------------------
# 좋은 질문입니다. 주식 시장의 변동성이 클 때는 “무엇을 사고파는가”뿐 아니라 “왜, 언제,얼마나”라는 투자 목적과 규칙을 엄격히 지키는 것이 더 중요합니다. 주어진 컨텍스트의 핵심 원칙(위험 분산, 투자목적에 맞는 증권선택, 큰 가격변동의 원인 이해)을 바탕으로 실용적 전략을 정리하면 다음과 같습니다.
#
# 공통 원칙(모든 투자자)
# - 위험 분산(포트폴리오 분산)을 강화: 자산(주식·채권·현금·대체투자)에 걸쳐 분산하여 개별 종목·섹터 리스크 완화.
# - 투자목적·시간수평·위험허용도 재확인: 단기 유동성 필요인지, 배당(소득) 의존인지, 장기 자본이득 목표인지에 따라 대응이 달라짐.
# - 현금(혹은 현금성자산) 확보: 급락 시 기회 구매용 또는 비상시 현금 필요 충족.
# - 기본(펀더멘털)에 집중: 좋은 기업의 수익성·부채·현금흐름 등 기초체력을 점검. 일시적 변동과 근본적 악화(실적·산업 구조 변화)를 구분.
# - 계획 준수: 미리 정한 자산배분·리밸런싱 규칙과 손절·목표매수 규칙을 마련하고 감정적 매매를 피함.
#
# 투자자 유형별 권장 전략
# - 사업 잉여금(기업의 여유자금): 안전·전환성·가격안정성이 핵심. 단기·중기 국채·우량 회사채·고품질 단기 상품·우량 단기 투자등급 채권·현금 비중 확대. 주식 비중 축소 권장.
# - 투자소득에 의존하는 개인: 안전성과 충분한 수익률 동시 확보. 배당 우량주·투자등급 채권·지속 가능한 배당 ETF·우선주 등으로 방어적 포트폴리오 구성. 변동성 큰 종목은 비중 축소.
# - 소득에 의존하지 않는 장기 투자자(성장 중시): 변동성은 매수 기회로 활용 가능. DCA(정액투자)로 가격 평균화, 우수 성장주·업종별 분산 매수, 단기 노이즈에 흔들리지 않도록 장기계획 유지.
#
# 전술적 수단(리스크 관리)
# - 리밸런싱: 자산배분이 깨지면 규칙적으로 되돌림(매도·매수).
# - 달러 코스트 애버리징(DCA): 변동성 큰 시기에 일시적으로 큰 금액 투자 위험을 줄임.
# - 헤지: 필요시 포트폴리오 일부에 옵션(보호풋)·인버스 상품 등으로 하방 위험 관리(복잡하므로 이해가 있을 때만).
# - 레버리지·마진 축소: 변동성 클 때 레버리지는 손실 증폭. 가능한 한 줄임.
# - 주문 방식 활용: 시장가 대신 지정가·분할매수로 급격한 슬리피지 방지.
#
# 심리적·실무적 조언
# - 단기 잡음에 과민 반응하지 말 것. 큰 가격 움직임의 원인(거시·정책·유동성 변화 등)을 이해하려 노력.
# - 포트폴리오와 목표가 일치하지 않다면 재설계할 것.
# - 필요하면 전문가(재무설계사·투자전문가)와 상담.
#
# 요약: 변동성은 리스크이자 기회입니다. 핵심은 분산·유동성 확보·투자목적에 맞는 안전성 선택과, 사전에 세운 규칙을 감정 없이 지키는 것입니다. 필요하면 귀하의 투자목적(예: 단기 유동성 필요 여부, 소득 의존도, 투자기간)을 알려주시면 보다 구체적인 포트폴리오 제안을 드리겠습니다.
